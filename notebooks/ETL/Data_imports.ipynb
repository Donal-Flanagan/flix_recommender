# %%
import os
import requests
import zipfile
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from pprint import pprint as pp

# %% [markdown]
# # Import data from MovieLens

# %%
url = "http://files.grouplens.org/datasets/movielens/ml-latest-small.zip"

# Create the 'data' directory if it doesn't exist
data_dir = '../data'
os.makedirs(data_dir, exist_ok=True)

# Save the ZIP file inside the 'data' directory
zip_path = os.path.join(data_dir, 'ml-latest-small.zip')

# Get the data
response = requests.get(url, stream=True)

# Save the data
with open(zip_path, 'wb') as file:
    for chunk in response.iter_content(chunk_size=1024):
        if chunk:
            file.write(chunk)

# Extract the ZIP file within the 'data' directory
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    # zip_ref.extractall()
    for member in zip_ref.namelist():
        target_path = os.path.join(data_dir, member)
        zip_ref.extract(member, path=data_dir)

print(f"Dataset downloaded and extracted to: {data_dir}")
# Out:
# Dataset downloaded and extracted to: ../data

# %% [markdown]
# ## Check the links data

# %%
links_df = pd.read_csv(
    '../data/ml-latest-small/links.csv', 
    usecols=['movieId', 'imdbId', 'tmdbId'],
    dtype={'movieId': int, 'imdbId': str, 'tmdbId': str}
)
links_df
# Out:
#       movieId   imdbId  tmdbId
# 0           1  0114709     862
# 1           2  0113497    8844
# 2           3  0113228   15602
# 3           4  0114885   31357
# 4           5  0113041   11862
# ...       ...      ...     ...
# 9737   193581  5476944  432131
# 9738   193583  5914996  445030
# 9739   193585  6397426  479308
# 9740   193587  8391976  483455
# 9741   193609  0101726   37891
#
# [9742 rows x 3 columns]

# %%
"""
When I initially loaded the imdbId values as ints, some had only 6 digits and were missing
a preceding 0 which caused them to no correspond to the correct IMDB url. When loaded as 
strings, they appear to have the preceding 0s but we need to check this.
"""

# Check for imdbIds of the wrong length.
links_df[links_df.imdbId.apply(lambda x:len(x)!=7)]
# Out:
# Empty DataFrame
# Columns: [movieId, imdbId, tmdbId]
# Index: []

# %%
# Check for NaN vals
print(links_df.isna().sum())
# Out:
# movieId    0
# imdbId     0
# tmdbId     8
# dtype: int64

# %%
''' 
We need to make sure these movieIds are filtered out of the other datasets because we are training
the Matrix Factorization model on the tmdb data (see web-scraping section below) and we need all the models to be working on the same data.
'''

links_df[links_df.isna().tmdbId==True]
# Out:
#       movieId   imdbId tmdbId
# 624       791  0113610    NaN
# 843      1107  0102336    NaN
# 2141     2851  0081454    NaN
# 3027     4051  0056600    NaN
# 5532    26587  0092337    NaN
# 5854    32600  0377059    NaN
# 6059    40697  0105946    NaN
# 7382    79299  0874957    NaN

# %% [markdown]
# ## Filter out movies with missing tmdbIds

# %% [markdown]
# ### movies.csv

# %%
movies_missing_tmdfIds = links_df[links_df.isna().tmdbId==True]

movies_df = pd.read_csv('../data/ml-latest-small/movies.csv')
movies_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies_df.shape
# Out:
# (9742, 3)

# %%
""" These don't look like popular movies anyway. """
movies_df[movies_df.index.isin(movies_missing_tmdfIds.index)]
# Out:
#       movieId                                              title  \
# 624       791  Last Klezmer: Leopold Kozlowski, His Life and ...
# 843      1107                                       Loser (1991)
# 2141     2851                                    Saturn 3 (1980)
# 3027     4051  Horrors of Spider Island (Ein Toter Hing im Ne...
# 5532    26587                    Decalogue, The (Dekalog) (1989)
# 5854    32600                                        Eros (2004)
# 6059    40697                                          Babylon 5
# 7382    79299         No. 1 Ladies' Detective Agency, The (2008)
#
#                          genres
# 624                 Documentary
# 843                      Comedy
# 2141  Adventure|Sci-Fi|Thriller
# 3027              Horror|Sci-Fi
# 5532        Crime|Drama|Romance
# 5854                      Drama
# 6059                     Sci-Fi
# 7382       Comedy|Crime|Mystery

# %%
""" The eight movies have been removed. """
movies_df = movies_df[~movies_df.index.isin(movies_missing_tmdfIds.index)]
movies_df.shape
# Out:
# (9734, 3)

# %% [markdown]
# ### ratings.csv

# %%
ratings_df = pd.read_csv('../data/ml-latest-small/ratings.csv')
ratings_df.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
ratings_df.shape
# Out:
# (100836, 4)

# %%
"""
Let's just double check how much data we're dropping.
-> No big deal. These 8 movies have only been rated once or twice anyway.
"""
ratings_df[ratings_df.movieId.isin(movies_missing_tmdfIds.movieId)]
# Out:
#        userId  movieId  rating   timestamp
# 282         3     2851     5.0  1306463925
# 14095      90      791     4.0   856354451
# 16539     105    26587     5.0  1446573090
# 23344     160     1107     3.5  1077749409
# 30090     210    40697     4.0  1527266191
# 31391     217     2851     3.0   955942393
# 42665     288     2851     2.0  1020369199
# 44588     298     1107     0.5  1479065495
# 69291     448     4051     0.5  1263237066
# 72810     469     2851     3.0   965335989
# 79088     489    79299     3.0  1332774632
# 83380     528    40697     0.5  1391736467
# 98357     606    32600     3.5  1171410642

# %%
""" Remove the movies. """
ratings_df = ratings_df[~ratings_df.movieId.isin(movies_missing_tmdfIds.movieId)]
ratings_df.shape
# Out:
# (100823, 4)

# %% [markdown]
# ### tags.csv

# %%
tags_df = pd.read_csv('../data/ml-latest-small/tags.csv')
tags_df.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
tags_df.shape
# Out:
# (3683, 4)

# %%
""" Remove the movies. """
tags_df = tags_df[~tags_df.movieId.isin(movies_missing_tmdfIds.movieId)]
tags_df.shape
# Out:
# (3683, 4)

# %% [markdown]
# ### links.csv

# %%
print(f"Num links before: {links_df.shape[0]}")
links_df = links_df[~links_df.movieId.isin(movies_missing_tmdfIds.movieId)]
print(f"Num links after: {links_df.shape[0]}")
# Out:
# Num links before: 9742
# Num links after: 9734

# %% [markdown]
# ## Overwrite the CSVs

# %%
movies_df.to_csv('../data/ml-latest-small/movies.csv', index=False)
ratings_df.to_csv('../data/ml-latest-small/ratings.csv', index=False)
tags_df.to_csv('../data/ml-latest-small/tags.csv', index=False)
links_df.to_csv('../data/ml-latest-small/links.csv', index=False)

# %% [markdown]
# ## Reload the data and check the size

# %%
movies_df = pd.read_csv('../data/ml-latest-small/movies.csv')
ratings_df = pd.read_csv('../data/ml-latest-small/ratings.csv')
tags_df = pd.read_csv('../data/ml-latest-small/tags.csv')
links_df = pd.read_csv(
    '../data/ml-latest-small/links.csv', 
    usecols=['movieId', 'imdbId', 'tmdbId'],
    dtype={'movieId': int, 'imdbId': str, 'tmdbId': str}
)

print(f"movies_df shape: {movies_df.shape}")
print(f"ratings_df shape: {ratings_df.shape}")
print(f"tags_df shape: {tags_df.shape}")
print(f"links_df shape: {links_df.shape}")

links_df.head()
# Out:
# movies_df shape: (9734, 3)
# ratings_df shape: (100823, 4)
# tags_df shape: (3683, 4)
# links_df shape: (9734, 3)
#    movieId   imdbId tmdbId
# 0        1  0114709    862
# 1        2  0113497   8844
# 2        3  0113228  15602
# 3        4  0114885  31357
# 4        5  0113041  11862

# %% [markdown]
# # Scrape metadata

# %% [markdown]
# ## Check links

# %%
""" IMDB doesn't allow webscraping. """

imdbid = '0114709'

url = f"https://www.imdb.com/title/tt{imdbid}/"
response = requests.get(url)

soup_imdb = BeautifulSoup(response.content, 'html.parser')

# %%
print(soup_imdb.prettify)
# Out:
# <bound method Tag.prettify of <html>
# <head><title>403 Forbidden</title></head>
# <body>
# <center><h1>403 Forbidden</h1></center>
# </body>
# </html>
# >

# %%
movieId = 1
url = f"https://movielens.org/movies/{str(movieId)}/"
response = requests.get(url)

soup_movie_lens = BeautifulSoup(response.content, 'html.parser')
print(soup_movie_lens.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" xmlns="http://www.w3.org/1999/html"> <!--<![endif]-->
# <head>
# <base href="/"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>MovieLens</title>
# <meta content="" name="description"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <!-- do not cache this page, please, to make upgrades easier -->
# <meta content="no-store, must-revalidate" http-equiv="Cache-control"/>
# <!-- favicon. thanks to realfavicongenerator.net -->
# <link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/manifest.json" rel="manifest"/>
# <meta content="#2b5797" name="msapplication-TileColor"/>
# <meta content="#ffffff" name="theme-color"/>
# <link href="https://fonts.googleapis.com/css?family=Raleway|Roboto" rel="stylesheet"/>
# <link href="/humans.txt" rel="author" type="text/plain">
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-42433938-3"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#       gtag('config', 'UA-42433938-3', { 'send_page_view': false });
#     </script>
# <link href="/app.be9bdefc4840590890e4.css" rel="stylesheet"/></link></head>
# <body data-bs-theme="light" id="root">
# <!--[if lt IE 7]>
#       <p class="chromeframe">You are using an outdated browser. <a href="http://browsehappy.com/">Upgrade your browser today</a> or <a href="http://www.google.com/chromeframe/?redirect=true">install Google Chrome Frame</a> to better experience this site.</p>
#     <![endif]-->
# <!--[if lt IE 9]>
#       <script src="/components/es5-shim/es5-shim.min.js"></script>
#       <script src="/components/json3/lib/json3.min.js"></script>
#     <![endif]-->
# <!-- application content -->
# <ui-view></ui-view>
# <script src="/polyfills.be9bdefc4840590890e4.js" type="text/javascript"></script><script src="/vendor.be9bdefc4840590890e4.js" type="text/javascript"></script><script src="/app.be9bdefc4840590890e4.js" type="text/javascript"></script></body>
# </html>
# >

# %%
""" 
themoviedb.org turned out to be the best option. 
It has a list of Directors, Screenwriters, etc as well as well as a short list of top-billed actors, rather than an extensive list of every single actor in the movie.
"""

tmdbId = '862'

url = f"https://www.themoviedb.org/movie/{?}/"
response = requests.get(url)

soup = BeautifulSoup(response.content, 'html.parser')
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html class="no-js" lang="de">
# <head>
# <title>Toy Story (1995) — The Movie Database (TMDB)</title>
# <meta content="on" http-equiv="cleartype"/>
# <meta charset="utf-8"/>
# <meta content="Movies, TV Shows, Streaming, Reviews, API, Actors, Actresses, Photos, User Ratings, Synopsis, Trailers, Teasers, Credits, Cast" name="keywords"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <meta content="Als Andys Lieblingspuppe hat Woody im Kinderzimmer das Sagen. Kaum ist der Junge nicht da, erwacht die Cowboy-Figur zum Leben, und mit ihm auch all das andere Spielzeug um ihn herum. Aufgeregt debattiert man über Andys bevorstehenden Geburtstag. Es wird befürchtet, daß ihr Besitzer ein neues Geschenk bevorzugen wird. Und tatsächlich: Der Neuankömmling Buzz Lightyear, ein stolzer Space Ranger, avanciert zu Andys Favoriten. Diese Herabstufung will Woody nicht hinnehmen." name="description"/>
# <meta content="/assets/2/v4/icons/mstile-144x144-30e7905a8315a080978ad6aeb71c69222b72c2f75d26dab1224173a96fecc962.png" name="msapplication-TileImage"/>
# <meta content="#032541" name="msapplication-TileColor"/>
# <meta content="#032541" name="theme-color"/>
# <link href="/assets/2/apple-touch-icon-57ed4b3b0450fd5e9a0c20f34e814b82adaa1085c79bdde2f00ca8787b63d2c4.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/assets/2/favicon-32x32-543a21832c8931d3494a68881f6afcafc58e96c5d324345377f3197a37b367b5.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/assets/2/favicon-16x16-b362d267873ce9c5a39f686a11fe67fec2a72ed25fa8396c11b71aa43c938b11.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/manifest.json?version=3" rel="manifest"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story" rel="canonical"/>
# <link href="/opensearch.xml" rel="search" title="TMDB Search" type="application/opensearchdescription+xml"/>
# <link as="font" crossorigin="" href="/assets/2/Consensus-3cba2c4d050ea63dbf7783173d288faf9ecb2942515a5e7f6e1beecabb2eaf72.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/assets/2/source-sans-pro-v14-vietnamese_latin-ext_latin_greek-ext_greek_cyrillic-ext_cyrillic-regular-f38472b9e378b8c936f55a92677f575ab69e414d7cc3706ecfefeacd994b7975.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/assets/2/source-sans-pro-v14-vietnamese_latin-ext_latin_greek-ext_greek_cyrillic-ext_cyrillic-italic-48273a74acbc1611b6ef1d0a771bb8ef042b9922b51d5bff560571dddcb5542a.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/assets/2/source-sans-pro-v14-vietnamese_latin-ext_latin_greek-ext_greek_cyrillic-ext_cyrillic-300-db9f15a13a9f8b8bc46db7756ab863e8834bd20a7a1124c4c0a5a8f7892f3e99.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/assets/2/source-sans-pro-v14-vietnamese_latin-ext_latin_greek-ext_greek_cyrillic-ext_cyrillic-600-6a087a74d78fc7d7b97fa1b0911c4ff3be4ff0bd5144618fd7ddc63ef1777f3a.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/assets/2/source-sans-pro-v14-vietnamese_latin-ext_latin_greek-ext_greek_cyrillic-ext_cyrillic-700-d67f7dff97d105f4ac5616b00fc7822ce2c33f653ece2f547995e6a71bb7b993.woff2" rel="preload" type="font/woff2"/>
# <link href="/assets/2/tailwind-fab14dbe53247b1a9bc49558d6ba2ad864de966b17617dd451289cc23af1ab2d.css" media="screen" rel="stylesheet"/>
# <link href="/assets/2/v4/fonts-dcbded27193f5556450c516bf4b553e851bc6d1c8d1c8e6da45a57e3fc278cff.css" media="screen" rel="stylesheet"/>
# <link href="/assets/2/application-857ce935d2dd41debe66031509b6a7c79c0f0e61f55db964be34178e65f6e0df.css" media="screen" rel="stylesheet"/>
# <link href="/assets/2/v4/media-c1f9581d4dd663bb6ad31ee77d75f0bd6d7e7f0549b767e38d1e651a919170dc.css" media="screen" rel="stylesheet"/>
# <link href="/assets/2/v4/ott-c3774eb59363af08e5e722efd17eb679e70cbb8f4f28d6f16d5550cf5c27bcac.css" media="screen" rel="stylesheet"/>
# <link href="/assets/2/v4/image-c101d89190c67ff940ff3d3c1fb30844e14cb1203b76cf66286cbad840d150b5.css" media="screen" rel="stylesheet"/>
# <meta content="Toy Story" property="og:title"/>
# <meta content="Als Andys Lieblingspuppe hat Woody im Kinderzimmer das Sagen. Kaum ist der Junge nicht da, erwacht die Cowboy-Figur zum Leben, und mit ihm auch all das andere Spielzeug um ihn herum. Aufgeregt debattiert man über Andys bevorstehenden Geburtstag. Es wird befürchtet, daß ihr Besitzer ein neues Geschenk bevorzugen wird. Und tatsächlich: Der Neuankömmling Buzz Lightyear, ein stolzer Space Ranger, avanciert zu Andys Favoriten. Diese Herabstufung will Woody nicht hinnehmen." property="og:description"/>
# <meta content="https://media.themoviedb.org/t/p/w500/om4fMx3e4xkx27sAsacoFP4WiEd.jpg" property="og:image"/>
# <meta content="https://media.themoviedb.org/t/p/w780/3Rfvhy1Nl6sSGJwyjb0QiZzZYlB.jpg" property="og:image"/>
# <meta content="video.movie" property="og:type"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="https://www.themoviedb.org/movie/862-toy-story" property="og:url"/>
# <meta content="The Movie Database" property="og:site_name"/>
# <meta content="141280979243998" property="fb:app_id"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story" hreflang="x-default" rel="alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=ar-SA" hreflang="ar-SA" rel="alternate"/>
# <meta content="ar_SA" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=be-BY" hreflang="be-BY" rel="alternate"/>
# <meta content="be_BY" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=bg-BG" hreflang="bg-BG" rel="alternate"/>
# <meta content="bg_BG" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=bs-BS" hreflang="bs-BS" rel="alternate"/>
# <meta content="bs_BS" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=ca-ES" hreflang="ca-ES" rel="alternate"/>
# <meta content="ca_ES" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=cs-CZ" hreflang="cs-CZ" rel="alternate"/>
# <meta content="cs_CZ" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=da-DK" hreflang="da-DK" rel="alternate"/>
# <meta content="da_DK" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=de-DE" hreflang="de-DE" rel="alternate"/>
# <meta content="de_DE" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=el-GR" hreflang="el-GR" rel="alternate"/>
# <meta content="el_GR" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=en-US" hreflang="en-US" rel="alternate"/>
# <meta content="en_US" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=es-ES" hreflang="es-ES" rel="alternate"/>
# <meta content="es_ES" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=es-MX" hreflang="es-MX" rel="alternate"/>
# <meta content="es_MX" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=et-EE" hreflang="et-EE" rel="alternate"/>
# <meta content="et_EE" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=fa-IR" hreflang="fa-IR" rel="alternate"/>
# <meta content="fa_IR" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=fi-FI" hreflang="fi-FI" rel="alternate"/>
# <meta content="fi_FI" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=fr-CA" hreflang="fr-CA" rel="alternate"/>
# <meta content="fr_CA" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=fr-FR" hreflang="fr-FR" rel="alternate"/>
# <meta content="fr_FR" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=he-IL" hreflang="he-IL" rel="alternate"/>
# <meta content="he_IL" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=hr-HR" hreflang="hr-HR" rel="alternate"/>
# <meta content="hr_HR" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=hu-HU" hreflang="hu-HU" rel="alternate"/>
# <meta content="hu_HU" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=id-ID" hreflang="id-ID" rel="alternate"/>
# <meta content="id_ID" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=is-IS" hreflang="is-IS" rel="alternate"/>
# <meta content="is_IS" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=it-IT" hreflang="it-IT" rel="alternate"/>
# <meta content="it_IT" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=ja-JP" hreflang="ja-JP" rel="alternate"/>
# <meta content="ja_JP" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=ka-GE" hreflang="ka-GE" rel="alternate"/>
# <meta content="ka_GE" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=ko-KR" hreflang="ko-KR" rel="alternate"/>
# <meta content="ko_KR" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=lt-LT" hreflang="lt-LT" rel="alternate"/>
# <meta content="lt_LT" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=lv-LV" hreflang="lv-LV" rel="alternate"/>
# <meta content="lv_LV" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=nb-NO" hreflang="nb-NO" rel="alternate"/>
# <meta content="nb_NO" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=nl-NL" hreflang="nl-NL" rel="alternate"/>
# <meta content="nl_NL" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=no-NO" hreflang="no-NO" rel="alternate"/>
# <meta content="no_NO" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=pl-PL" hreflang="pl-PL" rel="alternate"/>
# <meta content="pl_PL" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=pt-BR" hreflang="pt-BR" rel="alternate"/>
# <meta content="pt_BR" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=pt-PT" hreflang="pt-PT" rel="alternate"/>
# <meta content="pt_PT" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=ro-RO" hreflang="ro-RO" rel="alternate"/>
# <meta content="ro_RO" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=ru-RU" hreflang="ru-RU" rel="alternate"/>
# <meta content="ru_RU" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=sk-SK" hreflang="sk-SK" rel="alternate"/>
# <meta content="sk_SK" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=sl-SI" hreflang="sl-SI" rel="alternate"/>
# <meta content="sl_SI" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=sr-RS" hreflang="sr-RS" rel="alternate"/>
# <meta content="sr_RS" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=sv-SE" hreflang="sv-SE" rel="alternate"/>
# <meta content="sv_SE" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=th-TH" hreflang="th-TH" rel="alternate"/>
# <meta content="th_TH" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=tr-TR" hreflang="tr-TR" rel="alternate"/>
# <meta content="tr_TR" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=uk-UA" hreflang="uk-UA" rel="alternate"/>
# <meta content="uk_UA" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=uz-UZ" hreflang="uz-UZ" rel="alternate"/>
# <meta content="uz_UZ" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=vi-VN" hreflang="vi-VN" rel="alternate"/>
# <meta content="vi_VN" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=zh-CN" hreflang="zh-CN" rel="alternate"/>
# <meta content="zh_CN" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=zh-HK" hreflang="zh-HK" rel="alternate"/>
# <meta content="zh_HK" property="og:locale:alternate"/>
# <link href="https://www.themoviedb.org/movie/862-toy-story?language=zh-TW" hreflang="zh-TW" rel="alternate"/>
# <meta content="zh_TW" property="og:locale:alternate"/>
# <script src="/assets/2/jquery-3.7.1.min-fc9a93dd241f6b045cbff0481cf4e1901becd0e12fb45166a8f17f95823f0b1a.js"></script>
# <script src="/assets/2/kendo.custom-858b6fdebd475fa1403dfd32a63fd6fd85aa32b4ece5ee63ef6d7631a3e09d9c.js" type="module"></script>
# <script src="/assets/2/application-f9c8347cb25c4f2fbf78e20e81098f391b40e2c8a5119512676564710cf1566c.js"></script>
# <script async="" src="/assets/2/pusher.min-9f51d49d90f7270e50cb33df7624f0e41466e2581a8d5684b3d0412e910b0767.js"></script>
# <script async="" src="/assets/2/nprogress-1833552fcc8da90ba237e12b2b5caeadb1e2e96b0a3eb980dcc87d51aac0918a.js"></script>
# <script async="" charset="UTF-8" data-domain-script="23223fbb-5c84-48df-836d-0a83fb7b2c03" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript"></script>
# <script>
#       window.mobileDevice = false;
#       detected_timezone = Intl.DateTimeFormat().resolvedOptions().timeZone;
#         timezone = detected_timezone;
#     </script>
# <script>
#         (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-5QWVXV');
#       </script>
# <script async="" src="https://srv.tunefindforfans.com/fruits/mangos.js"></script>
# </head>
# <body class="de v4">
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5QWVXV" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script charset="utf-8" type="text/javascript">
#       if (mobileDevice) {
#         import("/assets/2/kendo-2024.4.1112/mjs/kendo.mobile.scroller.js");
#       }
#
#       import("/assets/2/kendo-2024.4.1112/mjs/messages/kendo.messages.de-DE.js").catch(function() {
#         console.log("Couldn't load the specified messages.")
#       });
#
#       import("/assets/2/kendo-2024.4.1112/mjs/cultures/kendo.culture.de-DE.js").then(() => {
#         kendo.culture("de-DE");
#       }).catch(function() {
#         console.log("Couldn't load the specified culture.")
#       });
#
#
#       pageLoaded().then(function() {
#         function OptanonWrapper() {}
#
#           $.cachedScript("/assets/2/timeago/locales/jquery.timeago.de-DE-0ffef75ef54d6aeb447a731107054eb32bcd574f965b795a5864d5aa2b8857ce.js" ).done();
#       });
#
#         window.amplified = window.amplified || { init: [] };
#         amplified.init.push(function() {
#           amplified.setParams({ artist:"", song:"" });
#           amplified.pushAdUnit(100006536);
#           amplified.run();
#         });
#     </script>
# <div class="page_wrap movie_wrap">
# <header class="normal smaller no_animation smaller subtle show_search_false">
# <div class="content">
# <div class="sub_media">
# <div class="nav_wrapper">
# <a aria-label="Home" class="logo" href="/">
# <img alt="The Movie Database (TMDB)" height="20" src="/assets/2/v4/logos/v2/blue_short-8e7b30f73a4020692ccca9c88bafe5dcb6f8a62a4c6bc55cd9ba82bb2cd95f6c.svg" width="154"/>
# </a>
# <ul class="dropdown_menu navigation">
# <li>
# <a aria-label="Filme" class="no_click" href="/movie">Filme</a>
# <ul>
# <li><a aria-label="Beliebt" href="/movie">Beliebt</a></li>
# <li><a aria-label="Im Kino" href="/movie/now-playing">Im Kino</a></li>
# <li><a aria-label="Demnächst" href="/movie/upcoming">Demnächst</a></li>
# <li><a aria-label="Bestbewertet" href="/movie/top-rated">Bestbewertet</a></li>
# </ul>
# </li>
# <li>
# <a aria-label="Serien" class="no_click" href="/tv">Serien</a>
# <ul>
# <li><a aria-label="Beliebt" href="/tv">Beliebt</a></li>
# <li><a aria-label="Heute im TV" href="/tv/airing-today">Heute im TV</a></li>
# <li><a aria-label="Im TV" href="/tv/on-the-air">Im TV</a></li>
# <li><a aria-label="Bestbewertet" href="/tv/top-rated">Bestbewertet</a></li>
# </ul>
# </li>
# <li>
# <a aria-label="Personen" class="no_click" href="/person">Personen</a>
# <ul>
# <li><a aria-label="Beliebte Personen" href="/person">Beliebte Personen</a></li>
# </ul>
# </li>
# <li>
# <a aria-label="Mehr" class="no_click" href="#">Mehr</a>
# <ul>
# <li><a aria-label="Diskussionen" href="/discuss">Diskussionen</a></li>
# <li><a aria-label="Rangliste" href="/leaderboard">Rangliste</a></li>
# <li><a aria-label="Support" href="/talk">Support</a></li>
# <li><a aria-label="API" href="https://developer.themoviedb.org/docs" target="_blank">API</a></li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="flex">
# <ul class="primary">
# <li class="glyph new_buttons">
# <a aria-label="Create New Movie or TV Show" class="new_icon no_click" href="#">
# <span class="glyphicons_v2 plus white"></span>
# </a>
# </li>
# <li class="translate">
# <div>de</div>
# </li>
# <li><a aria-label="Anmelden" href="/login">Anmelden</a></li>
# <li><a aria-label="TMDB beitreten" href="/signup">TMDB beitreten</a></li>
# <li class="glyph search_buttons">
# <a aria-label="Search" class="search" href="/search"><span class="glyphicons_v2 search blue"></span></a>
# <a aria-label="Search" class="close hide" href="/search"><span class="glyphicons_v2 menu-close invert svg"></span></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="search_bar hide">
# <section class="search show_search_false">
# <div class="sub_media">
# <form accept-charset="utf-8" action="/search" id="search_form" method="get">
# <label>
# <input autocomplete="off" autocorrect="off" autofill="off" dir="auto" id="search_v4" name="query" placeholder="Suche nach Film, Serie, Person" spellcheck="false" type="text" value=""/>
# </label>
# <input disabled="" type="submit"/>
# </form>
# </div>
# </section>
# </div>
# </header>
# <main class="smaller subtle show_search_false" id="main">
# <section class="inner_content movie_content backdrop poster">
# <style>
#     html {
#       --primaryColor: rgba(10.5, 115.5, 178.5, 1);
#       --primaryColorContrast: #ffffff;
#     }
#
#     div.header {
#       background: linear-gradient(to bottom right, rgba(10.5, 115.5, 178.5, 1), rgba(10.5, 115.5, 178.5, 0.84));
#     }
#
#     div.column_wrapper div.settings_panel h3 {
#       color: var(--primaryColorContrast);
#     }
#
#     div.settings_panel h3.background_color {
#       background-color: var(--primaryColor);
#     }
#
#     section.inner_content a, section.media_panel div.menu ul li.active a {
#       color: #000;
#     }
#
#     section.inner_content a:hover {
#       color: rgba(0,0,0,0.5);
#     }
#
#     section.media_panel div.menu ul li.active {
#       border-bottom-color: #000000;
#     }
#
#       section.inner_content div.header div.single_column *, section.inner_content div.header div.single_column a {
#         color: #fff;
#       }
#
#       section.inner_content div.header div.single_column a:hover {
#         color: rgba(255,255,255,0.7);
#       }
#
#       section.inner_content div.header div.single_column div.facts span.certification {
#         border: 1px solid rgba(255,255,255,0.6);
#         color: rgba(255,255,255,0.6);
#       }
#
#       p.new_button.rounded a span, section.inner_content section.header ul.actions li.video span,
#       div.column_wrapper div.settings_panel h3 span.glyphicons_v2, section.inner_content section.header div.trailer a span,
#       div.second_header .vibes_tooltip {
#         filter: invert(1);
#       }
#
#     p.new_button.rounded, section.content_score div.content_score div, div.leaderboard div.histogram div.bar span {
#       border-color: var(--primaryColor);
#       background-color: var(--primaryColor);
#       color: var(--primaryColorContrast);
#     }
#
#     p.new_button.rounded a, section.content_score div.content_score div p {
#       color: var(--primaryColorContrast);
#     }
#
#     ul.consensus_reaction_items li {
#       background-color: var(--primaryColor);
#     }
#
#     div.vibes_label {
#       color: var(--primaryColorContrast);
#     }
#
#       div.header.large.first {
#         border-bottom: 1px solid var(--primaryColor);
#         background-position: left calc((50vw - 170px) - 340px) top;
#         background-size: cover;
#         background-repeat: no-repeat;
#         background-image: url('https://media.themoviedb.org/t/p/w1920_and_h800_multi_faces/3Rfvhy1Nl6sSGJwyjb0QiZzZYlB.jpg');
#       }
#
#       @media only screen and (min-width: 1900px) {
#         div.header.large.first {
#           background-size: auto;
#         }
#       }
#
#       section.inner_content div.custom_bg {
#         background-image: linear-gradient(to right, rgba(10.5, 115.5, 178.5, 1) calc((50vw - 170px) - 340px), rgba(10.5, 115.5, 178.5, 0.84) 50%, rgba(10.5, 115.5, 178.5, 0.84) 100%);
#       }
# </style>
# <div class="scroller_wrap shortcut_bar_wrapper should_fade is_fading" id="shortcut_bar_scroller">
# <ul class="dropdown_menu scroller" id="new_shortcut_bar">
# <li class="true">
#       Übersicht
#
#       <ul class="media group">
# <li><a href="/movie/862-toy-story">Hauptseite</a></li>
# <li><a href="/movie/862-toy-story/titles">Alternativtitel</a></li>
# <li><a href="/movie/862-toy-story/cast">Besetzung &amp; Crew</a></li>
# <li><a href="/movie/862-toy-story/releases">Veröffentlichungen</a></li>
# <li><a href="/movie/862-toy-story/translations">Übersetzungen</a></li>
# <li><a href="/movie/862-toy-story/watch">Jetzt anschauen</a></li>
# <li class="spacer"><a href="/movie/862-toy-story/changes" title="Änderungsverlauf">Änderungsverlauf</a></li>
# </ul>
# </li>
# <li class="false">
#       Media
#
#       <ul class="media number_group">
# <li><a href="/movie/862-toy-story/images/backdrops">Hintergrundbilder <span class="k-menu-expand-arrow"><span class="count">43</span></span></a></li>
# <li><a href="/movie/862-toy-story/images/logos">Logos <span class="k-menu-expand-arrow"><span class="count">25</span></span></a></li>
# <li><a href="/movie/862-toy-story/images/posters">Poster <span class="k-menu-expand-arrow"><span class="count">127</span></span></a></li>
# <li>
#           Videos
#
#           <ul class="number_group">
# <li><a href="/movie/862-toy-story/videos?active_nav_item=Trailers">Trailer <span class="k-menu-expand-arrow"><span class="count">1</span></span></a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="false">
#       Fandom
#
#       <ul class="media">
# <li>
#           Diskussionen
#
#           <ul class="number_group">
# <li><a href="/movie/862-toy-story/discuss">Handlung</a></li>
# <li><a href="/movie/862-toy-story/discuss/category/5047951f760ee3318900009a">Allgemein <span class="k-menu-expand-arrow"><span class="count">5</span></span></a></li>
# <li><a href="/movie/862-toy-story/discuss/category/504794a319c29527aa000640">Inhaltsfehler <span class="k-menu-expand-arrow"><span class="count">5</span></span></a></li>
# </ul>
# </li>
# <li><a href="/movie/862-toy-story/reviews">Rezensionen</a></li>
# </ul>
# </li>
# <li>
#       Teilen
#
#       <ul class="media">
# <li><a class="no_click" href="#" id="share" title="Teilen">Link teilen</a></li>
# <li><a href="https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Fwww.themoviedb.org%2Fmovie%2F862-toy-story" rel="noopener" target="_blank">Facebook</a></li>
# <li><a href="https://twitter.com/intent/tweet?url=https%3A%2F%2Fwww.themoviedb.org%2Fmovie%2F862-toy-story&amp;text=Toy Story @themoviedb&amp;related=themoviedb" rel="noopener" target="_blank">Tweet</a></li>
# </ul>
# </li>
# </ul>
# </div>
# <script>
#   $(function() {
#     initializeScroller(mobileDevice, '#shortcut_bar_scroller');
#
#     $("#new_shortcut_bar").kendoMenu({
#       hoverDelay: 0,
#       activate: function(e) {
#       }
#     });
#   });
# </script>
# <div class="header large border first" fetchpriority="high">
# <div class="keyboard_s custom_bg">
# <div class="single_column">
# <section class="images inner" id="original_header">
# <div class="poster_wrapper true">
# <div class="poster">
# <div class="image_content">
# <div class="blurred" style="background-image: url('https://media.themoviedb.org/t/p/w300_and_h450_multi_faces_filter(blur)/om4fMx3e4xkx27sAsacoFP4WiEd.jpg');">
# <img alt="Toy Story" class="poster w-full" src="https://media.themoviedb.org/t/p/w300_and_h450_bestv2/om4fMx3e4xkx27sAsacoFP4WiEd.jpg" srcset="https://media.themoviedb.org/t/p/w300_and_h450_bestv2/om4fMx3e4xkx27sAsacoFP4WiEd.jpg 1x, https://media.themoviedb.org/t/p/w600_and_h900_bestv2/om4fMx3e4xkx27sAsacoFP4WiEd.jpg 2x"/>
# </div>
# </div>
# <div class="zoom">
# <a class="no_click" href="#"><span class="glyphicons_v2 fullscreen white"></span> Erweitern</a>
# </div>
# </div>
# <div class="ott_offer">
# <div class="text_wrapper">
# <div class="loading_wrapper">
# <div class="ball-scale-multiple loader white">
# <div></div>
# <div></div>
# <div></div>
# </div>
# </div>
# <div class="button">
# <div class="provider">
# <img alt="Als Stream verfügbar on Disney Plus" height="36" src="https://media.themoviedb.org/t/p/original/97yvRBw1GzX7fXprcF80er19ot.jpg" width="36"/>
# </div>
# <div class="text">
# <span>
# <h4>Als Stream verfügbar</h4>
# <h3><a class="no_click" href="/movie/862-toy-story/watch" title="Als Stream verfügbar on Disney Plus">Jetzt anschauen</a></h3>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="header_poster_wrapper true">
# <section class="header poster">
# <div class="title ott_true" dir="auto">
# <h2 class="9">
# <a href="/movie/862-toy-story">Toy Story</a>
# <span class="tag release_date">(1995)</span>
# </h2>
# <div class="facts">
# <span class="certification">
#         0
#       </span>
# <span class="release">
#         21.03.1996 (DE)
#       </span>
# <span class="genres">
# <a href="/genre/16-animation/movie">Animation</a>, <a href="/genre/12-abenteuer/movie">Abenteuer</a>, <a href="/genre/10751-familie/movie">Familie</a>, <a href="/genre/35-komoedie/movie">Komödie</a>
# </span>
# <span class="runtime">
#         1h 21m
#     </span>
# </div>
# </div>
# <div class="flex flex-col">
# <div class="auto actions !mb-0">
# <div class="flex items-center">
# <div class="flex items-center justify-center space-2 mr-4" id="consensus_pill">
# <div class="chart flex items-center justify-center !mr-0">
# <div class="consensus details">
# <div class="outer_ring">
# <div class="user_score_chart" data-bar-color="#21d07a" data-percent="80" data-track-color="#204529">
# <div class="percent">
# <span class="icon icon-r80"></span>
# </div>
# </div>
# </div>
# </div>
# <div class="text font-bold ml-1">Benutzerbewertung</div>
# <ul class="consensus_reaction_items ml-4">
# <li class="!mx-0 w-9 h-9 bg-tmdb-dark-blue" title="Grinning face"><img class="w-7 h-7" src="/assets/2/v8/1f600-f53b445a86235a4ef54899ad2f1a936e3ff6d1dcdaafc9ed63d6a6070491c0a1.svg"/></li>
# <li class="!mx-0 w-9 h-9 bg-tmdb-dark-blue" title="Smiling face with heart eyes"><img class="w-7 h-7" src="/assets/2/v8/1f60d-f12478ffe50d98da9d6cafbf29ef1777b8d1d2bb123224c978ca9ba4e6e6159b.svg"/></li>
# </ul>
# </div>
# </div>
# <div class="group flex items-center justify-center space-2 rating_false reactions_false bg-tmdb-dark-blue rounded-full cursor-pointer hover:scale-105 transition ease-in-out duration-150" id="vibes_label">
# <div class="flex items-center justify-center">
# <div class="flex items-center text-white font-bold cursor-pointer transform" id="vibes_content">
# <div class="flex flex-nowrap items-center whitespace-nowrap">
#     Wie ist dein <span class="flex pl-1 underline underline-offset-2 decoration-2 decoration-tmdb-light-blue">Vibe</span>?
#     <span class="glyphicons_v2 circle-info !invert ml-1" data-element="vibes_label" id="vibes_tooltip"></span>
# </div>
# <div class="vibes_tooltip hide">
# <p>Logge dich ein, um TMDBs neues Bewertungssystem zu benutzen.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <ul class="auto actions">
# <li class="tooltip use_tooltip list tooltip_hover" title="Log dich ein um benutzerdefinierte Listen zu erstellen.">
# <a class="no_click" href="#"><span class="glyphicons_v2 thumbnails-list white"></span></a>
# </li>
# <li class="tooltip use_tooltip" title="Anmelden, um diesen Film deinen Favoriten hinzuzufügen">
# <a class="no_click add_to_account_list favourite" href="#" id="favourite"><span class="glyphicons_v2 heart white false"></span></a>
# </li>
# <li class="tooltip use_tooltip" title="Anmelden, um diesen Film deiner Watchliste hinzuzufügen">
# <a class="no_click add_to_account_list watchlist" href="#" id="watchlist"><span class="glyphicons_v2 bookmark white false"></span></a>
# </li>
# <div class="flex items-center hide" id="vibes_mobile_tooltip_item">
# <li class="flex flex-col items-center justify-center tooltip use_tooltip tooltip_hover" id="vibes_mobile_item" title="Logge dich ein, um TMDBs neues Bewertungssystem zu benutzen.">
# <a class="no_click rating" href="#" id="rate_it"><span class="flex glyphicons_v2 star white false"></span></a>
# </li>
# <div class="vibes_mobile_panel_tooltip hide">
# <p>Willkommen zu Vibes, TMDBs neuem Bewertungssystem. Für mehr Information, besuche die <span class="italic underline underline-offset-2"><a href="/bible/general#65dd0c6c7314a13a50071ddb"> Beitragsbibel</a></span>.</p>
# </div>
# </div>
# <li class="video none flex items-center ml-1">
# <a class="no_click play_trailer" data-id="l4iH6rYa8cU" data-site="YouTube" data-title="Trailer abspielen" href="#"><span class="glyphicons_v2 play"></span> Trailer abspielen</a>
# </li>
# </ul>
# </div>
# <div class="header_info">
# <h3 class="tagline" dir="auto">Hang on for the comedy that goes to infinity and beyond!</h3>
# <h3 dir="auto">Handlung</h3>
# <div class="overview" dir="auto">
# <p>Als Andys Lieblingspuppe hat Woody im Kinderzimmer das Sagen. Kaum ist der Junge nicht da, erwacht die Cowboy-Figur zum Leben, und mit ihm auch all das andere Spielzeug um ihn herum. Aufgeregt debattiert man über Andys bevorstehenden Geburtstag. Es wird befürchtet, daß ihr Besitzer ein neues Geschenk bevorzugen wird. Und tatsächlich: Der Neuankömmling Buzz Lightyear, ein stolzer Space Ranger, avanciert zu Andys Favoriten. Diese Herabstufung will Woody nicht hinnehmen.</p>
# </div>
# <ol class="people no_image">
# <li class="profile">
# <p><a href="/person/7879-john-lasseter">John Lasseter</a></p>
# <p class="character">Director, Story</p>
# </li>
# <li class="profile">
# <p><a href="/person/7-andrew-stanton">Andrew Stanton</a></p>
# <p class="character">Screenplay, Story</p>
# </li>
# <li class="profile">
# <p><a href="/person/12893-alec-sokolow">Alec Sokolow</a></p>
# <p class="character">Screenplay</p>
# </li>
# <li class="profile">
# <p><a href="/person/12891-joss-whedon">Joss Whedon</a></p>
# <p class="character">Screenplay</p>
# </li>
# <li class="profile">
# <p><a href="/person/12892-joel-cohen">Joel Cohen</a></p>
# <p class="character">Screenplay</p>
# </li>
# <li class="profile">
# <p><a href="/person/7911-joe-ranft">Joe Ranft</a></p>
# <p class="character">Story</p>
# </li>
# <li class="profile">
# <p><a href="/person/12890-pete-docter">Pete Docter</a></p>
# <p class="character">Story</p>
# </li>
# </ol>
# </div>
# </section>
# </div>
# </section>
# <div class="hidden" id="ott_offers_window">
# </div>
# </div>
# </div>
# </div>
# <script charset="utf-8" type="text/javascript">
#   function showOTTOffers() {
#       if ( $("#rating_details_window").data("kendoWindow") ) {
#         $("#rating_details_window").data("kendoWindow").close();
#       }
#     $('div.custom_bg').addClass('ott_bg');
#     $('#original_header').addClass('hide');
#     $('#ott_offers_window').removeClass('hidden');
#   }
#
#   function hideOTTOffers() {
#     $('div.custom_bg').removeClass('ott_bg');
#     $('#ott_offers_window').addClass('hidden');
#     $('#original_header').removeClass('hide');
#   }
#
#   function toggleOTTOffers(state) {
#     if ( state.event == 'hideOTTOffers' ) {
#       hideOTTOffers();
#     } else if ( state.event == 'showOTTOffers' ) {
#       showOTTOffers();
#     }
#   }
#
#   function pushOttState(state) {
#     history.pushState(state, null, state.href);
#     toggleOTTOffers(state);
#   }
#
#   function loadDropDown() {
#     var ott_country_datasource = new kendo.data.DataSource({
#       data: [{"country_code":"AL","native_name":"Albanien","flag":"/assets/2/flags_v2/48/AL-c484c009f5ea9fea49556008d43190384ef8f7276a8248e0fb47fbe532a2c834.png"},{"country_code":"DZ","native_name":"Algerien","flag":"/assets/2/flags_v2/48/DZ-ac97f91e52d33c3c5e5481c62a1a0c53a3726133d233e934ecb805931ddbe0f8.png"},{"country_code":"AD","native_name":"Andorra","flag":"/assets/2/flags_v2/48/AD-94531c9fa3fc7b91a70b53dde5badcb0ad8f66dfbd466862689bf67029c37157.png"},{"country_code":"AO","native_name":"Angola","flag":"/assets/2/flags_v2/48/AO-adcfe12b9c19dad22213163af00f45c2eac0bf0ea8f93a649b90922affceac3b.png"},{"country_code":"AG","native_name":"Antigua und Barbuda","flag":"/assets/2/flags_v2/48/AG-11a801f43f4190c71c56fe8fb948cd3d5bf5b3b5bed0713cf5fe284a0af97a0a.png"},{"country_code":"AR","native_name":"Argentinien","flag":"/assets/2/flags_v2/48/AR-af53c8037def87d38995d642d93f899f5e4922ca62843dde5b5cc361771c3bf0.png"},{"country_code":"AZ","native_name":"Aserbaidschan","flag":"/assets/2/flags_v2/48/AZ-01aaccc6b81f819171d125e19920419b304d9044bac002e159a586f64b5842ee.png"},{"country_code":"AU","native_name":"Australien","flag":"/assets/2/flags_v2/48/AU-987875cfcb3626621074bb52ae1c72b43d15f51801aa8271888a32e25395b844.png"},{"country_code":"BS","native_name":"Bahamas","flag":"/assets/2/flags_v2/48/BS-85a403d8bd000c47e97becfea0a71f897da12a107a9d00a1f5f7308639174771.png"},{"country_code":"BH","native_name":"Bahrain","flag":"/assets/2/flags_v2/48/BH-5b206cea0074e9da028316b643168f0d3061d17dabd6cc328eb70999090844d9.png"},{"country_code":"BB","native_name":"Barbados","flag":"/assets/2/flags_v2/48/BB-ae56b0f3d593c89338f9595e63e0313cc67915842dd7a25cb115e84dfb8f13c0.png"},{"country_code":"BY","native_name":"Belarus","flag":"/assets/2/flags_v2/48/BY-2fbf6f41adba999379b228ca8ec668f4b88e5b6e98a42f343a848a5a6a936a6f.png"},{"country_code":"BE","native_name":"Belgien","flag":"/assets/2/flags_v2/48/BE-cc3358e59c409a83da1607f9bae3cd79c63cf28db983355863b68382ba097008.png"},{"country_code":"BZ","native_name":"Belize","flag":"/assets/2/flags_v2/48/BZ-9f6b1f3a1d62fc44dcf8364fcc6ec60d90d58cdc792cdd7a5a160a436b6f75ea.png"},{"country_code":"BM","native_name":"Bermuda","flag":"/assets/2/flags_v2/48/BM-b8cce80d1fb6f16c6695175a9a27c91ce1e2081b8caa0eb8e25f560accd51eeb.png"},{"country_code":"BO","native_name":"Bolivien","flag":"/assets/2/flags_v2/48/BO-8a539e324deac4c650ec2ba28f6c9e63787899d469adcc98350f8654325b3484.png"},{"country_code":"BA","native_name":"Bosnien und Herzegowina","flag":"/assets/2/flags_v2/48/BA-2b8cd0b97c50f0ef1ee435d3dab26bf39adcc26710ef7979651f31c2079a97eb.png"},{"country_code":"BR","native_name":"Brasilien","flag":"/assets/2/flags_v2/48/BR-9860aa017ee236029feb86e4a2f57a14d38d21a27798f7a4a533778a6ea6c06a.png"},{"country_code":"BG","native_name":"Bulgarien","flag":"/assets/2/flags_v2/48/BG-fb1949b0d995a0d9e254faab192a63d4e297df59fbc59b3dd83812d074a9f78a.png"},{"country_code":"BF","native_name":"Burkina Faso","flag":"/assets/2/flags_v2/48/BF-7b994176305c409a49c641371fc236144f36b4c48d8323eb182aa6d4c3c264d7.png"},{"country_code":"CL","native_name":"Chile","flag":"/assets/2/flags_v2/48/CL-b3ba3b4e958dc55a4732734d667f47a1703501a7baa19939d57912e9d8d9b50f.png"},{"country_code":"CR","native_name":"Costa Rica","flag":"/assets/2/flags_v2/48/CR-79f73010236e5d5ea1fbbfc099d9939b1a21542b237924f47eee49cdac09f97d.png"},{"country_code":"CI","native_name":"Côte d’Ivoire","flag":"/assets/2/flags_v2/48/CI-7b2b4fd0cabbd349d78e53fff2a92be6bbc792ab9146103e551ddc1e1b76a87e.png"},{"country_code":"DE","native_name":"Deutschland","flag":"/assets/2/flags_v2/48/DE-1877858abee51cabe053ceb7d0561f538597c5c1aca56ba25319abba343a9ca0.png"},{"country_code":"DO","native_name":"Dominikanische Republik","flag":"/assets/2/flags_v2/48/DO-eaf6f96469144edd422defd288375a3b1c4749c9547b808141ca77a3603b2f39.png"},{"country_code":"DK","native_name":"Dänemark","flag":"/assets/2/flags_v2/48/DK-fd8b7ed6b65fc796dab2c998bb9bf0c6151ebfa188ad939243a56c5089df696a.png"},{"country_code":"EC","native_name ...
#     });
#
#     var watch_url_template = "/movie/862-toy-story/watch?translate=false&locale={0}";
#     $("#ott_country_filter").kendoDropDownList({
#       filter: "contains",
#       height: 250,
#       autoWidth: true,
#       value: 'DE',
#       dataValueField: "country_code",
#       dataSource: ott_country_datasource,
#       valueTemplate: '<span class="dropdown_flag" style="background-image: url(\'#:data.flag#\')"></span><span>#:data.native_name#</span>',
#       template: '<span class="dropdown_flag" style="background-image: url(\'#:data.flag#\')"></span><span>#: data.native_name #</span>',
#       change: function(e) {
#         window.location = kendo.format(watch_url_template, this.value());
#       },
#       filtering: function(e) {
#         var filterValue = e.filter != undefined ? e.filter.value : "";
#         e.preventDefault();
#
#         this.dataSource.filter({
#           logic: "or",
#           filters: [
#             {
#               field: "country_code",
#               operator: "contains",
#               value: filterValue
#             },
#             {
#               field: "native_name",
#               operator: "contains",
#               value: filterValue
#             }
#           ]
#         });
#       }
#     });
#   }
#
#   var offersHasLoaded = false;
#
#   $(function() {
#     if ( offersHasLoaded ) {
#       loadDropDown();
#     }
#
#       window.history.replaceState({ href: '/movie/862-toy-story', event: 'hideOTTOffers' }, null, '/movie/862-toy-story');
#
#       $('div.ott_offer').on('click', function(e) {
#         e.preventDefault();
#
#         $('html, body').animate({ scrollTop: 0 }, 0);
#         if ( offersHasLoaded == false ) {
#           $('div.ott_offer div.text_wrapper').addClass('loading');
#
#           $.ajax({
#             url: '/movie/862-toy-story/remote/watch?translate=false&locale=DE',
#             type: 'GET',
#             beforeSend: function() {
#              activatePageLoader();
#             }
#           }).fail(function() {
#             deactivatePageLoader();
#             $('div.ott_offer div.text_wrapper').removeClass('loading');
#             showError('There was a problem.');
#           }).done(function(response) {
#             deactivatePageLoader();
#             offersHasLoaded = true;
#             $('div.ott_offer div.text_wrapper').removeClass('loading');
#             $('#ott_offers_window').html(response);
#
#             loadDropDown();
#             pushOttState({ href: '/movie/862-toy-story/watch', event: 'showOTTOffers' });
#           });
#         } else if ( $('#ott_offers_window').hasClass('hidden') ) {
#           pushOttState({ href: '/movie/862-toy-story/watch', event: 'showOTTOffers' });
#         }
#       });
#
#       $('div.header.large div.single_column').on('click', 'ul.filters li a', function(e) {
#         $('ul.filters li a').removeClass('selected');
#         $(this).addClass('selected');
#
#         var selected_quality = $(this).data('panel');
#         var selected_items = $('ul.providers li.' + selected_quality);
#
#         $('ul.providers li').addClass('hide');
#         selected_items.removeClass('hide');
#
#         $("ul.providers").each(function(index) {
#           var items = $(this).find('.' + selected_quality);
#           if (items.length == 0) {
#             $(this).closest('div.ott_provider').addClass('hide');
#           } else {
#             $(this).closest('div.ott_provider').removeClass('hide');
#           }
#         });
#       });
#
#     $('div.header.large div.single_column').on('click', '#ott_offers_window a.close', function(e) {
#       pushOttState({ href: '/movie/862-toy-story', event: 'hideOTTOffers' });
#     });
#   });
# </script>
# <div class="media movie_v4 header_large" id="media_v4">
# <div class="column_wrapper">
# <div class="content_wrapper">
# <div>
# <div class="white_column">
# <section class="panel top_billed scroller">
# <h3 dir="auto">Hauptdarsteller</h3>
# <div class="scroller_wrap should_fade is_fading" id="cast_scroller">
# <ol class="people scroller">
# <li class="card">
# <a href="/person/31-tom-hanks">
# <div class="glyphicons_v2 picture grey profile no_image_holder two">
# <img alt="Tom Hanks" class="profile w-full" loading="lazy" src="https://media.themoviedb.org/t/p/w138_and_h175_face/eKF1sGJRrZJbfBG1KirPt1cfNd3.jpg" srcset="https://media.themoviedb.org/t/p/w138_and_h175_face/eKF1sGJRrZJbfBG1KirPt1cfNd3.jpg 1x, https://media.themoviedb.org/t/p/w276_and_h350_face/eKF1sGJRrZJbfBG1KirPt1cfNd3.jpg 2x"/>
# </div>
# </a>
# <p><a href="/person/31-tom-hanks">Tom Hanks</a></p>
# <p class="character">Woody (voice)</p>
# </li>
# <li class="card">
# <a href="/person/12898-tim-allen">
# <div class="glyphicons_v2 picture grey profile no_image_holder two">
# <img alt="Tim Allen" class="profile w-full" loading="lazy" src="https://media.themoviedb.org/t/p/w138_and_h175_face/woWhZzFILVhYMAvsPL171HjMY0y.jpg" srcset="https://media.themoviedb.org/t/p/w138_and_h175_face/woWhZzFILVhYMAvsPL171HjMY0y.jpg 1x, https://media.themoviedb.org/t/p/w276_and_h350_face/woWhZzFILVhYMAvsPL171HjMY0y.jpg 2x"/>
# </div>
# </a>
# <p><a href="/person/12898-tim-allen">Tim Allen</a></p>
# <p class="character">Buzz Lightyear (voice)</p>
# </li>
# <li class="card">
# <a href="/person/7167-don-rickles">
# <div class="glyphicons_v2 picture grey profile no_image_holder two">
# <img alt="Don Rickles" class="profile w-full" loading="lazy" src="https://media.themoviedb.org/t/p/w138_and_h175_face/iJLQV4dcbTUgxlWJakjDldzlMXS.jpg" srcset="https://media.themoviedb.org/t/p/w138_and_h175_face/iJLQV4dcbTUgxlWJakjDldzlMXS.jpg 1x, https://media.themoviedb.org/t/p/w276_and_h350_face/iJLQV4dcbTUgxlWJakjDldzlMXS.jpg 2x"/>
# </div>
# </a>
# <p><a href="/person/7167-don-rickles">Don Rickles</a></p>
# <p class="character">Mr. Potato Head (voice)</p>
# </li>
# <li class="card">
# <a href="/person/12899-jim-varney">
# <div class="glyphicons_v2 picture grey profile no_image_holder two">
# <img alt="Jim Varney" class="profile w-full" loading="lazy" src="https://media.themoviedb.org/t/p/w138_and_h175_face/zvBFmvKUrPvE6FW35O3RP4i1ZPp.jpg" srcset="https://media.themoviedb.org/t/p/w138_and_h175_face/zvBFmvKUrPvE6FW35O3RP4i1ZPp.jpg 1x, https://media.themoviedb.org/t/p/w276_and_h350_face/zvBFmvKUrPvE6FW35O3RP4i1ZPp.jpg 2x"/>
# </div>
# </a>
# <p><a href="/person/12899-jim-varney">Jim Varney</a></p>
# <p class="character">Slinky Dog (voice)</p>
# </li>
# <li class="card">
# <a href="/person/12900-wallace-shawn">
# <div class="glyphicons_v2 picture grey profile no_image_holder two">
# <img alt="Wallace Shawn" class="profile w-full" loading="lazy" src="https://media.themoviedb.org/t/p/w138_and_h175_face/wVaM1WlFKDce4esThwL4XtNLhOe.jpg" srcset="https://media.themoviedb.org/t/p/w138_and_h175_face/wVaM1WlFKDce4esThwL4XtNLhOe.jpg 1x, https://media.themoviedb.org/t/p/w276_and_h350_face/wVaM1WlFKDce4esThwL4XtNLhOe.jpg 2x"/>
# </div>
# </a>
# <p><a href="/person/12900-wallace-shawn">Wallace Shawn</a></p>
# <p class="character">Rex (voice)</p>
# </li>
# <li class="card">
# <a href="/person/7907-john-ratzenberger">
# <div class="glyphicons_v2 picture grey profile no_image_holder two">
# <img alt="John Ratzenberger" class="profile w-full" loading="lazy" src="https://media.themoviedb.org/t/p/w138_and_h175_face/oRtDEOuIO1yDhTz5dORBdxXuLMO.jpg" srcset="https://media.themoviedb.org/t/p/w138_and_h175_face/oRtDEOuIO1yDhTz5dORBdxXuLMO.jpg 1x, https://media.themoviedb.org/t/p/w276_and_h350_face/oRtDEOuIO1yDhTz5dORBdxXuLMO.jpg 2x"/>
# </div>
# </a>
# <p><a href="/person/7907-john-ratzenberger">John Ratzenberger</a></p>
# <p class="character">Hamm (voice)</p>
# </li>
# <li class="card">
# <a href="/person/8873-annie-potts">
# <div class="glyphicons_v2 picture grey profile no_image_holder one">
# <img alt="Annie Potts" class="profile w-full" loading="lazy" src="https://media.themoviedb.org/t/p/w138_and_h175_face/hWIzkAH7jkSkxBfwdudxbSPxeno.jpg" srcset="https://media.themoviedb.org/t/p/w138_and_h175_face/hWIzkAH7jkSkxBfwdudxbSPxeno.jpg 1x, https://media.themoviedb.org/t/p/w276_and_h350_face/hWIzkAH7jkSkxBfwdudxbSPxeno.jpg 2x"/>
# </div>
# </a>
# <p><a href="/person/8873-annie-potts">Annie Potts</a></p>
# <p class="character">Bo Peep (voice)</p>
# </li>
# <li class="card">
# <a href="/person/1116442-john-morris">
# <div class="glyphicons_v2 picture grey profile no_image_holder two">
# <img alt="John Morris" class="profile w-full" loading="lazy" src="https://media.themoviedb.org/t/p/w138_and_h175_face/lSdNMhN3DoXEQJ37IeOD5mTMUQK.jpg" srcset="https://media.themoviedb.org/t/p/w138_and_h175_face/lSdNMhN3DoXEQJ37IeOD5mTMUQK.jpg 1x, https://media.themoviedb.org/t/p/w276_and_h350_face/lSdNMhN3DoXEQJ37IeOD5mTMUQK.jpg 2x"/>
# </div>
# </a>
# <p><a href="/person/1116442-john-morris">John Morris</a></p>
# <p class="character">Andy (voice)</p>
# </li>
# <li class="card">
# <a href="/person/12901-erik-von-detten">
# <div class="glyphicons_v2 picture grey profile no_image_holder two">
# <img alt="Erik von Detten" class="profile w-full" loading="lazy" src="https://media.themoviedb.org/t/p/w138_and_h175_face/7fHjKnLKmqzR0kmvRPLxpQE7BsK.jpg" srcset="https://media.themoviedb.org/t/p/w138_and_h175_face/7fHjKnLKmqzR0kmvRPLxpQE7BsK.jpg 1x, https://media.themoviedb.org/t/p/w276_and_h350_face/7fHjKnLKmqzR0kmvRPLxpQE7BsK.jpg 2x"/>
# </div>
# </a>
# <p><a href="/person/12901-erik-von-detten">Erik von Detten</a></p>
# <p class="character">Sid (voice)</p>
# </li>
# <li class="filler view_more">
# <p><a href="/movie/862-toy-story/cast">Mehr anzeigen <span class="glyphicons_v2 arrow-thin-right"></span></a></p>
# </li>
# </ol>
# <div class="style_wrapper"></div>
# </div>
# <p class="new_button"><a class="" href="/movie/862-toy-story/cast">Besetzung und Crew</a></p>
# </section>
# <section class="panel media_panel social_panel">
# <section class="review">
# <div class="menu">
# <h3 dir="auto">Social Media</h3>
# <ul>
# <li class="active" dir="auto"><a class="media_panel" href="#" id="reviews">Rezensionen <span>1</span></a></li>
# <li class="" dir="auto"><a class="media_panel" href="#" id="discussions">Diskussionen <span>10</span></a></li>
# </ul>
# </div>
# <div class="content">
# <div class="original_content">
# <div class="review_container one">
# <div class="content one">
# <div class="inner_content">
# <div class="content">
# <div class="inner_content">
# <div class="card">
# <div class="grouped">
# <div class="avatar">
# <a href="/u/Gnislew">
# <img alt="Michael" class="avatar" loading="lazy" src="https://secure.gravatar.com/avatar/2aef74e1c4e339e3d26eb24da44a223c.jpg?s=45" srcset="https://secure.gravatar.com/avatar/2aef74e1c4e339e3d26eb24da44a223c.jpg?s=45 1x, https://secure.gravatar.com/avatar/2aef74e1c4e339e3d26eb24da44a223c.jpg?s=90 2x"/>
# </a>
# </div>
# <div class="info">
# <h3><a href="/review/66aa117a56de99d36ae3c33e">Eine Rezension von Michael</a></h3>
# <div class="flex">
# <div class="rating_border rating"><span class="glyphicons_v2 star invert svg"></span> 100<span class="percent">%</span></div>
# <h5>Verfasst von <a href="/u/Gnislew">Michael</a> am 31. Juli 2024</h5>
# </div>
# </div>
# </div>
# <div class="teaser">
# ...
#               parameterMap: function() {
#                 return { query: $("#search_v4").data("kendoAutoComplete").value() };
#               }
#             },
#             schema: {
#               data: "results"
#             }
#           },
#           popup: {
#             appendTo: $("section.search")
#           },
#           filtering: function(e) {
#             var filter = e.filter != undefined ? e.filter.value : "";
#             if (filter == '') {
#               if ( ($('#search_v4-list #trending_search_header_template').length) == 0 ) {
#                 // $('#search_v4_listbox').empty();
#                 $('#search_v4-list').prepend($("#search_v4_headerTemplate").html());
#               }
#             } else {
#               $("#trending_search_header_template").remove();
#             }
#           },
#           select: function(e) {
#             processing_selected_item = true;
#             processSelectedItem(e);
#           },
#           close: function(e) {
#             // Use this to prevent the popup from closing in dev.
#             // e.preventDefault();
#           }
#         }).data("kendoAutoComplete");
#
#         $('#search_v4').keydown(function(event) {
#           if (event.keyCode == 13) {
#             if (processing_selected_item) {
#               return;
#             } else {
#               processSelectedItem(null);
#             }
#           }
#         });
#
#         $('header #search_form').submit(function() {
#           return false;
#         });
#
#         var autocompleteInput = $('section.search .k-autocomplete input');
#         autocompleteInput.on('focus', function (e) {
#           var value = autocompleteInput.val();
#           if (value == null || value == '') {
#             $("#search_v4").data("kendoAutoComplete").search('');
#           } else {
#             var fieldLength = value.length;
#             autocompleteInput[0].setSelectionRange(fieldLength, fieldLength);
#           }
#         });
#
#         $('header.show_search_false li.search_buttons a.search').on('click', function(e) {
#           e.preventDefault();
#           showSearch(true);
#         });
#
#         $('header.show_search_true li.search_buttons a.search').on('click', function(e) {
#           e.preventDefault();
#           $("#search_v4").data("kendoAutoComplete").focus();
#         });
#
#         $('header.show_search_false li.search_buttons a.close').on('click', function(e) {
#           e.preventDefault();
#           showSearch(false);
#         });
#
#         $('main.show_search_false').on('click', function(e) {
#           showSearch(false);
#         });
#
#         $('header span.k-i-close[title="clear"]').on('click', function(e) {
#           $('#search_v4').data("kendoAutoComplete").focus();
#         });
#
#
#         public_media_type_map = {
#           'movie': 'Film',
#           'tv': 'Serie',
#           'person': 'Person'
#         };
#
#
#         $(document).on('keydown', null, 'b', function() {
#           if ( $('a.keyboard_s.parent').length ) {
#             $('a.keyboard_s.parent')[0].click();
#           }
#         });
#
#         $(document).on('keyup', null, 's', function() {
#           if ( $('#search_v4').length ) {
#             if ( $('header').hasClass('show_search_false') ) {
#               showSearch(true);
#             } else {
#               $("#search_v4").data("kendoAutoComplete").focus();
#             }
#           }
#         });
#
#         $(document).on('keyup', null, 'shift+/', function() {
#           keyboard_shortcut_popup.open();
#         });
#
#         $(document).on('keydown', null, 'left', function() {
#           if ( $('span.previous a.keyboard_s').length ) {
#             $('span.previous a.keyboard_s')[0].click();
#           }
#         });
#
#         $(document).on('keydown', null, 'right', function() {
#           if ( $('span.next a.keyboard_s').length ) {
#             $('span.next a.keyboard_s')[0].click();
#           }
#         });
#
#         $(document).on('keydown', null, 'm', function() {
#           if ( $('#new_shortcut_bar').length ) {
#             $("#new_shortcut_bar").focus();
#           }
#         });
#       });
#
#       var gender_lookup = {
#         0: 'two',
#         1: 'one',
#         2: 'two',
#         3: 'two'
#       }
#     </script>
# <script id="person_template" type="text/x-kendo-tmpl">
#       <div class="item profile list_item grid_item">
#         <div class="image_content profile">
#           <a class="result" href="${data.url}" title="${data.name}" alt="${data.name}">
#             # if (data.profile_path) { #
#               <img class="" src="https://media.themoviedb.org/t/p/w66_and_h66_face${data.profile_path}" alt="${data.name}" width="45" height="45" srcset="https://media.themoviedb.org/t/p/w66_and_h66_face${data.profile_path} 1x, https://media.themoviedb.org/t/p/w132_and_h132_face${data.profile_path} 2x">
#             # } else { #
#               <div class="glyphicons_v2 picture profile ${gender_lookup[data.gender]} grey no_image_holder w45_and_h45"></div>
#             # } #
#           </a>
#         </div>
#
#         <div class="content">
#           <p class="name"><a class="result" href="${data.url}" title="${data.name}" alt="${data.name}">${data.name}</a></p>
#
#           # if (data.known_for) { #
#             <p class="sub">${data.known_for}</p>
#           # } #
#         </div>
#       </div>
#     </script>
# <script id="person_template_with_known_for" type="text/x-kendo-tmpl">
#       <div class="item profile list_item known_for">
#         <div class="image_content profile">
#           # if (data.profile_path) { #
#             <img class="" src="https://media.themoviedb.org/t/p/w66_and_h66_face${data.profile_path}" alt="${data.name}" width="45" height="45" srcset="https://media.themoviedb.org/t/p/w66_and_h66_face${data.profile_path} 1x, https://media.themoviedb.org/t/p/w132_and_h132_face${data.profile_path} 2x">
#           # } else { #
#             <div class="glyphicons_v2 picture grey no_image_holder w45_and_h45 profile"></div>
#           # } #
#         </div>
#
#         <div class="content">
#           <p class="name">${data.name}</p>
#           # if (data.known_for) { #
#             <p class="sub">${data.known_for_department} &bull; ${data.known_for}</p>
#           # } else { #
#             <p class="sub">No known credits.</p>
#           # } #
#         </div>
#       </div>
#     </script>
# <script id="person_result_template" type="text/x-kendo-tmpl">
#       <div class="ac_item profile list_item known_for">
#         <div class="image_content profile">
#           # if (data.profile_path) { #
#             <img class="" src="https://media.themoviedb.org/t/p/w66_and_h66_face${data.profile_path}" alt="${data.name}" width="45" height="45" srcset="https://media.themoviedb.org/t/p/w66_and_h66_face${data.profile_path} 1x, https://media.themoviedb.org/t/p/w132_and_h132_bestv2${data.profile_path} 2x">
#           # } else { #
#             <div class="glyphicons_v2 picture grey no_image_holder w45_and_h45 profile"></div>
#           # } #
#         </div>
#
#         <div class="content">
#           <p class="name">${data.name}</p>
#           # if (data.known_for) { #
#             <p class="sub">
#               # if (data.media_type) { #
#                 <span class="media_type person">#= public_media_type_map[data.media_type] # &bull; </span>
#               # } #
#               # for (var i = 0; i < data.known_for.length; i++) { #
#               <span class="comma">#= data.known_for[i].title ? data.known_for[i].title : data.known_for[i].name #</span>
#               # } #
#             </p>
#           # } else { #
#             <p class="sub">No known credits.</p>
#           # } #
#         </div>
#       </div>
#     </script>
# <script id="movie_result_template" type="text/x-kendo-tmpl">
#       <div class="ac_results">
#         <div class="ac_item poster list_item">
#           <div class="image_content poster">
#             # if (data.poster_path) { #
#               <img class="" src="https://media.themoviedb.org/t/p/w45_and_h67_bestv2${data.poster_path}" alt="${data.title}" width="45" height="67" srcset="https://media.themoviedb.org/t/p/w45_and_h67_bestv2${data.poster_path} 1x, https://media.themoviedb.org/t/p/w90_and_h134_bestv2${data.poster_path} 2x">
#             # } else { #
#               <div class="glyphicons_v2 picture grey no_image_holder w45_and_h67"></div>
#             # } #
#           </div>
#
#           <div class="content">
#             <p class="name">${data.title}</p>
#             <p class="sub">
#               # if (data.media_type) { #
#                 <span class="media_type movie">#= public_media_type_map[data.media_type] # &bull; </span>
#               # } #
#               # if (data.original_title !== data.title) { #
#                 <span class="comma"><span class="original_title">#= data.original_title #</span></span>
#               # } #
#               # if (data.release_date) { #
#                 <span class="comma"><span class="release_date">#= data.release_date #</span></span>
#               # } #
#             </p>
#           </div>
#         </div>
#       </div>
#     </script>
# <script id="tv_show_result_template" type="text/x-kendo-tmpl">
#       <div class="ac_item poster list_item">
#         <div class="image_content poster">
#           # if (data.poster_path) { #
#             <img class="" src="https://media.themoviedb.org/t/p/w45_and_h67_bestv2${data.poster_path}" alt="${data.title}" width="45" height="67" srcset="https://media.themoviedb.org/t/p/w45_and_h67_bestv2${data.poster_path} 1x, https://media.themoviedb.org/t/p/w90_and_h134_bestv2${data.poster_path} 2x">
#           # } else { #
#             <div class="glyphicons_v2 picture grey no_image_holder w45_and_h67"></div>
#           # } #
#         </div>
#
#         <div class="content">
#           <p class="name">${data.name}</p>
#           <p class="sub">
#             # if (data.media_type) { #
#                 <span class="media_type tv">#= public_media_type_map[data.media_type] # &bull; </span>
#               # } #
#             # if (data.original_name !== data.name) { #
#               <span class="comma"><span class="original_title">#= data.original_name #</span></span>
#             # } #
#             # if (data.first_air_date) { #
#               <span class="comma"><span class="release_date">#= data.first_air_date #</span></span>
#             # } #
#           </p>
#         </div>
#       </div>
#     </script>
# <script id="slim_movie_result_template" type="text/x-kendo-tmpl">
#       <div class="ac_item poster list_item">
#         <div class="image_content poster">
#           # if (data.poster_path) { #
#             <img class="" src="https://media.themoviedb.org/t/p/w45_and_h67_bestv2${data.poster_path}" alt="${data.title}" width="45" height="67" srcset="https://media.themoviedb.org/t/p/w45_and_h67_bestv2${data.poster_path} 1x, https://media.themoviedb.org/t/p/w90_and_h134_bestv2${data.poster_path} 2x">
#           # } else { #
#             <div class="glyphicons_v2 picture grey no_image_holder w45_and_h67"></div>
#           # } #
#         </div>
#
#         <div class="content">
#           <p class="name">${data.title}</p>
#           <p class="sub">
#             # if (data.original_title !== data.title) { #
#               <span class="comma"><span class="original_title">#= data.original_title #</span></span>
#             # } #
#             # if (data.release_date) { #
#               <span class="comma"><span class="release_date">#= data.release_date #</span></span>
#             # } #
#           </p>
#         </div>
#
#         <p><span class="media_type movie">#= public_media_type_map[data.media_type] #</span></p>
#       </div>
#     </script>
# <script id="multi_search_template" type="text/x-kendo-tmpl">
#       <div class="ac_results">
#         # if (data.media_type == 'movie') { #
#           #= kendo.render(kendo.template($("\\#movie_result_template").html()), [data]) #
#         # } else if (data.media_type == 'tv') { #
#           #= kendo.render(kendo.template($("\\#tv_show_result_template").html()), [data]) #
#         # } else if (data.media_type == 'person') { #
#           #= kendo.render(kendo.template($("\\#person_result_template").html()), [data]) #
#         # } #
#       </div>
#     </script>
# <script id="search_v4_headerTemplate" type="text/x-kendo-template">
#       <div id="trending_search_header_template" class="slim_search_results_header">
#         <div class="wrapper">
#           <h2><span class="glyphicons_v2 trending"></span> Trending</h2>
#         </div>
#       </div>
#     </script>
# <script id="search_no_data_template" type="text/x-kendo-template">
#       <div class="slim_search_results_header no_data">
#         <div class="wrapper">
#           <h2>Keine Ergebnisse</h2>
#         </div>
#       </div>
#     </script>
# <script id="slim_multi_search_template" type="text/x-kendo-tmpl">
#       # if (data.media_type == 'movie') { #
#         <div class="slim_search_results slim">
#           <div class="wrapper">
#             <div class="glyphicons_v2 film"></div>
#             <p>#= data.name # <span>Nach Filmen</span></p>
#           </div>
#         </div>
#       # } else if (data.media_type == 'tv') { #
#         <div class="slim_search_results slim">
#           <div class="wrapper">
#             <div class="glyphicons_v2 tv"></div>
#             <p>#= data.name # <span>Nach Serien</span></p>
#           </div>
#         </div>
#       # } else if (data.media_type == 'person') { #
#         <div class="slim_search_results slim">
#           <div class="wrapper">
#             <div class="glyphicons_v2 user"></div>
#             <p>#= data.name # <span>Nach Personen</span></p>
#           </div>
#         </div>
#       # } else { #
#         <div class="slim_search_results slim">
#           <div class="wrapper">
#             <div class="glyphicons_v2 search"></div>
#             <p>#= data #</p>
#           </div>
#         </div>
#       # } #
#     </script>
# <script id="delete-confirmation" type="text/x-kendo-template">
#       <section class="window_content">
#         <p class="delete-message">Bist du dir sicher?</p>
#
#         <button class="delete-cancel k-button">Nein</button>
#         <button class="delete-confirm k-button">Ja</button>
#       </section>
#     </script>
# <div id="dialog_window"></div>
# <span class="hide" id="notification"></span>
# <script id="errorTemplate" type="text/x-kendo-template">
#       <div class="notification error">
#         <span>
#           <h2><span class="glyphicons_v2 circle-alert invert svg"></span> #= title #</h2>
#           # if (message instanceof Array) { #
#             <ul>
#               # for (var i = 0; i < message.length; i++) { #
#                 <li>#= message[i] #</li>
#               # } #
#             </ul>
#           # } else { #
#             <p>#= message #</p>
#           # } #
#         </span>
#       </div>
#     </script>
# <script id="successTemplate" type="text/x-kendo-template">
#       <div class="notification success">
#         <span>
#           <h2><span class="glyphicons_v2 circle-check invert svg"></span> #= title #</h2>
#           <p>#= message #</p>
#         </span>
#       </div>
#     </script>
# <script id="network_combo_template" type="text/x-kendo-tmpl">
#       <span class="k-state-default image">
#         # if (data.logo_path) { #
#           <img src="https://media.themoviedb.org/t/p/h15${data.logo_path}" alt="${data.name}" srcset="https://media.themoviedb.org/t/p/h15${data.logo_path} 1x, https://media.themoviedb.org/t/p/h30${data.logo_path} 2x" height="15">&nbsp;&nbsp;-&nbsp;
#         # } #
#         ${data.name}# if (data.origin_country) { # (${data.origin_country}) # } #
#       </span>
#     </script>
# <script type="application/ld+json">
#       {
#         "@context": "http://schema.org",
#         "@type": "WebSite",
#         "name": "The Movie Database",
#         "alternateName": "TMDB",
#         "url": "https://www.themoviedb.org"
#       }
#     </script>
# <script type="application/ld+json">
#       {
#          "@context": "http://schema.org",
#          "@type": "WebSite",
#          "url": "https://www.themoviedb.org/",
#          "potentialAction": {
#            "@type": "SearchAction",
#            "target": "https://www.themoviedb.org/search?query={search_term_string}",
#            "query-input": "required name=search_term_string"
#          }
#       }
#     </script>
# </body>
# </html>
# >

# %% [markdown]
# ## web-scraping from themoviedb.org
# To improve our recommendations it would be beneficial to train a similarity model on the people associated with the movies.
# <br>
# The themoviedb.org page for each movie contains information on the people involved in the production of the movies under tags such as "Screenplay", "Story", "Director" and "Characters", as well as a list of top-billed actors.
# <br>
# The tags are not consistent across all movies. For example, "Characters" usually has a value such as "Stan Lee", who created the characters but was not involved in producing the movies. Many movies do not have this tag at all.
# <br>
# Stan Lee is obviously a very relevant name to associate with a movie though, as people who like one Marvel movie will tend to like other Marvel movies.
#
# It is may not be necessary to save the roles of the people. Clint Eastwood is both an actor and a director and his fans will probably be consistent across both roles.
# <br>
# Then again, Jordan Peele was a comedy actor and the movies he has directed are most definitely not comedies (Get Out).
# <br>
# We are going to be using this data for Matrix Factorization which is a technique for reducing dimensionality and finding latent features. In layman's terms this means finding groups of similar things which often go together, such as Quentin Tarantino or Wes Anderson often using the same actors.
#
# Movies with the same actor will probably have a weaker connection than movies with the same director. Brad Pitt has been in two Tarantino movies but he was also Thelma & Louise. All Tarantino movies have a similar style but actors might star in movies from totally different genres.
#
# So let's leave in the jobs (feature engineering). It will make our dataset bigger and sparser but its not a huge dataset anyway so we should be fine.

# %%
""" 
To figure out where the relevant information is in the big mess of html that is the soup, we inspect the actual webpage in the browser using DevTools, and find the elements we are after. 

For example, we can find John Lasseter's name and job in the html code below.

<li class="profile">
<p><a href="/person/7879-john-lasseter">John Lasseter</a></p>
<p class="character">Director, Story</p>
</li>

"""

creator_list = soup.find('ol', class_='people no_image')

if creator_list:
    profiles = creator_list.find_all('li', class_='profile')
    for person in profiles:
        name = person.find('a').text
        jobs = person.find('p', class_='character').text
        
        jobs = jobs.split(',') if ',' in jobs else [jobs]
        jobs = [r.strip() for r in jobs] 
    
        for job in jobs:
            print(f"{name} ({job})")
else:
    print(f"Creator list not found for movie {movieId}")

actor_list = soup.find('ol', class_='people scroller')

if actor_list:
    actors = actor_list.find_all('li', class_='card') 
    for actor in actors:
        name_tag = actor.find('img', alt=True)
        actor_name = name_tag['alt'] if name_tag else "Unknown"
        
        print(f"{actor_name} (Actor)")
else:
    print(f"Actor list not found for movie {movieId}")
# Out:
# John Lasseter (Director)
# John Lasseter (Story)
# Andrew Stanton (Screenplay)
# Andrew Stanton (Story)
# Alec Sokolow (Screenplay)
# Joss Whedon (Screenplay)
# Joel Cohen (Screenplay)
# Joe Ranft (Story)
# Pete Docter (Story)
# Tom Hanks (Actor)
# Tim Allen (Actor)
# Don Rickles (Actor)
# Jim Varney (Actor)
# Wallace Shawn (Actor)
# John Ratzenberger (Actor)
# Annie Potts (Actor)
# John Morris (Actor)
# Erik von Detten (Actor)

# %%
# Locate the <img> tag with the class 'poster'
poster_img_tag = soup.find('img', class_='poster w-full')

# Extract the 'src' attribute, which contains the poster link
if poster_img_tag:
    poster_link = poster_img_tag.get('src')
    print(f"Poster Link: {poster_link}")
else:
    print("Poster not found.")
# Out:
# Poster Link: https://media.themoviedb.org/t/p/w300_and_h450_bestv2/om4fMx3e4xkx27sAsacoFP4WiEd.jpg

# %% [markdown]
# ### Scrape the data

# %%
class tmdbWebScraper:
    def __init__(self):
        self.

def _scrape_movie_metadata_from_tmdb(movie_row):
    movie_id = movie_row.movieId
    tmdb_id = movie_row.tmdbId
    
    url = f"https://www.themoviedb.org/movie/{tmdb_id}/"
    response = requests.get(url)    
    soup = BeautifulSoup(response.content, 'html.parser')

    people = []

    crew_list = soup.find('ol', class_='people no_image')
    if crew_list:
        crew = crew_list.find_all('li', class_='profile')
        for person in crew:
            name = person.find('a').text
            jobs = person.find('p', class_='character').text
            jobs = [job.strip() for job in jobs.split(',')]
            for job in jobs:
                people.append((movie_id, name, job))

    cast_list = soup.find('ol', class_='people scroller')
    if cast_list:
        cast = cast_list.find_all('li', class_='card')
        for actor in cast:
            name_tag = actor.find('img', alt=True)
            actor_name = name_tag['alt'] if name_tag else "Unknown"
            people.append((movie_id, actor_name, 'Actor'))
    
    poster_img_tag = soup.find('img', class_='poster w-full')
    if poster_img_tag:
        poster_link = (movie_id, poster_img_tag.get('src'))
    else:
        print(f"Poster not found for movieId: {movie_id}.")
        poster_link = None

    return people, poster_link

def aggregate_movie_cast_and_crew(links_df):

    print("Beginning movie cast & crew data aggregation.")
    
    num_links = links_df.shape[0]
    i = 0
    
    movie_people = []
    poster_links = []
    
    for index, movie_row in links_df.iterrows():
    
        movie_cast_and_crew, poster_link = _scrape_movie_metadata_from_tmdb(movie_row)

        movie_people.extend(movie_cast_and_crew)
        if poster_link:
            poster_links.append(poster_link)
     
        percent_completed = i/num_links*100
        if percent_completed % 5 == 0 and percent_completed > 0:
            print(f"{percent_completed}% completed")
        i+= 1

    print("Data aggregation complete.")

    movie_people_df = pd.DataFrame(movie_people, columns=['movieId', 'name', 'role'])
    poster_links_df = pd.DataFrame(poster_links, columns=['movieId', 'poster_link'])
    
    

    return movie_people_df, poster_links_df

def save_aggregated_data(df, movie_dir_path, filename):
    df.to_csv(movie_dir_path+filename, index=False)
    print(f"Data saved to {movie_dir_path} dir")

# %%
movie_dir_path = '../data/ml-latest-small/'

movie_people_df, poster_links_df = aggregate_movie_cast_and_crew(links_df)
save_aggregated_data(movie_people_df, movie_dir_path, filename='movie_cast_and_crew.csv')
save_aggregated_data(poster_links_df, movie_dir_path, filename='poster_links.csv')
# Out:
# Beginning movie cast & crew data aggregation.
# Poster not found for movieId: 310.
# Poster not found for movieId: 311.
# Poster not found for movieId: 363.
# Poster not found for movieId: 364.
# Poster not found for movieId: 365.
# Poster not found for movieId: 430.
# Poster not found for movieId: 431.
# Poster not found for movieId: 432.
# Poster not found for movieId: 433.
# Poster not found for movieId: 434.
# Poster not found for movieId: 435.
# Poster not found for movieId: 1128.
# Poster not found for movieId: 1129.
# Poster not found for movieId: 1130.
# Poster not found for movieId: 1131.
# Poster not found for movieId: 1132.
# Poster not found for movieId: 1135.
# Poster not found for movieId: 1136.
# Poster not found for movieId: 1137.
# Poster not found for movieId: 1439.
# Poster not found for movieId: 1440.
# Poster not found for movieId: 1441.
# Poster not found for movieId: 1442.
# Poster not found for movieId: 1445.
# Poster not found for movieId: 1446.
# Poster not found for movieId: 1447.
# Poster not found for movieId: 1449.
# Poster not found for movieId: 1453.
# Poster not found for movieId: 1454.
# Poster not found for movieId: 1456.
# Poster not found for movieId: 1457.
# Poster not found for movieId: 1549.
# Poster not found for movieId: 1550.
# Poster not found for movieId: 1551.
# Poster not found for movieId: 1552.
# Poster not found for movieId: 1554.
# Poster not found for movieId: 1556.
# Poster not found for movieId: 1562.
# Poster not found for movieId: 1564.
# Poster not found for movieId: 1627.
# Poster not found for movieId: 1629.
# Poster not found for movieId: 1631.
# Poster not found for movieId: 1633.
# Poster not found for movieId: 1635.
# Poster not found for movieId: 1639.
# Poster not found for movieId: 1641.
# Poster not found for movieId: 1642.
# Poster not found for movieId: 1643.
# Poster not found for movieId: 1707.
# Poster not found for movieId: 1711.
# Poster not found for movieId: 1713.
# Poster not found for movieId: 1812.
# Poster not found for movieId: 1816.
# Poster not found for movieId: 1821.
# Poster not found for movieId: 1824.
# Poster not found for movieId: 1825.
# Poster not found for movieId: 1826.
# Poster not found for movieId: 1827.
# Poster not found for movieId: 1829.
# Poster not found for movieId: 1831.
# Poster not found for movieId: 1833.
# Poster not found for movieId: 1834.
# Poster not found for movieId: 1835.
# Poster not found for movieId: 1836.
# Poster not found for movieId: 1920.
# Poster not found for movieId: 1921.
# Poster not found for movieId: 1922.
# Poster not found for movieId: 1923.
# Poster not found for movieId: 1924.
# Poster not found for movieId: 1926.
# Poster not found for movieId: 2088.
# Poster not found for movieId: 2089.
# Poster not found for movieId: 2090.
# Poster not found for movieId: 2091.
# Poster not found for movieId: 2092.
# Poster not found for movieId: 2093.
# Poster not found for movieId: 2094.
# Poster not found for movieId: 2095.
# Poster not found for movieId: 2096.
# Poster not found for movieId: 2097.
# Poster not found for movieId: 2098.
# Poster not found for movieId: 2099.
# Poster not found for movieId: 2100.
# Poster not found for movieId: 2102.
# Poster not found for movieId: 2159.
# Poster not found for movieId: 2241.
# Poster not found for movieId: 2243.
# Poster not found for movieId: 2244.
# Poster not found for movieId: 2245.
# Poster not found for movieId: 2247.
# Poster not found for movieId: 2248.
# Poster not found for movieId: 2314.
# Poster not found for movieId: 2315.
# Poster not found for movieId: 2316.
# Poster not found for movieId: 2318.
# Poster not found for movieId: 2320.
# Poster not found for movieId: 2321.
# Poster not found for movieId: 2322.
# Poster not found for movieId: 2496.
# Poster not found for movieId: 2497.
# Poster not found for movieId: 2498.
# Poster not found for movieId: 2500.
# Poster not found for movieId: 2501.
# Poster not found for movieId: 2502.
# Poster not found for movieId: 2632.
# Poster not found for movieId: 2633.
# Poster not found for movieId: 2709.
# Poster not found for movieId: 2710.
# Poster not found for movieId: 2712.
# Poster not found for movieId: 2713.
# Poster not found for movieId: 3147.
# Poster not found for movieId: 3148.
# Poster not found for movieId: 3150.
# Poster not found for movieId: 3225.
# Poster not found for movieId: 3230.
# Poster not found for movieId: 3235.
# Poster not found for movieId: 3238.
# Poster not found for movieId: 3240.
# Poster not found for movieId: 3241.
# Poster not found for movieId: 3243.
# Poster not found for movieId: 3244.
# Poster not found for movieId: 3246.
# Poster not found for movieId: 3247.
# Poster not found for movieId: 3248.
# Poster not found for movieId: 3249.
# Poster not found for movieId: 3397.
# Poster not found for movieId: 3398.
# Poster not found for movieId: 3400.
# Poster not found for movieId: 3401.
# Poster not found for movieId: 3402.
# Poster not found for movieId: 3403.
# Poster not found for movieId: 3404.
# Poster not found for movieId: 3405.
# Poster not found for movieId: 3406.
# Poster not found for movieId: 3408.
# Poster not found for movieId: 3409.
# Poster not found for movieId: 3410.
# Poster not found for movieId: 3412.
# Poster not found for movieId: 3414.
# Poster not found for movieId: 3477.
# Poster not found for movieId: 3478.
# Poster not found for movieId: 3479.
# Poster not found for movieId: 3480.
# Poster not found for movieId: 3481.
# Poster not found for movieId: 3483.
# Poster not found for movieId: 3484.
# Poster not found for movieId: 3632.
# Poster not found for movieId: 3633.
# Poster not found for movieId: 3634.
# Poster not found for movieId: 3635.
# Poster not found for movieId: 3637.
# Poster not found for movieId: 3638.
# Poster not found for movieId: 3639.
# Poster not found for movieId: 3640.
# Poster not found for movieId: 3641.
# Poster not found for movieId: 3643.
# Poster not found for movieId: 3646.
# Poster not found for movieId: 3706.
# Poster not found for movieId: 3707.
# Poster not found for movieId: 3708.
# Poster not found for movieId: 3709.
# Poster not found for movieId: 3770.
# Poster not found for movieId: 3919.
# Poster not found for movieId: 3920.
# Poster not found for movieId: 3922.
# Poster not found for movieId: 3925.
# Poster not found for movieId: 3926.
# Poster not found for movieId: 3927.
# Poster not found for movieId: 3928.
# Poster not found for movieId: 3929.
# Poster not found for movieId: 3930.
# Poster not found for movieId: 3932.
# Poster not found for movieId: 3996.
# Poster not found for movieId: 4063.
# Poster not found for movieId: 4064.
# Poster not found for movieId: 4065.
# Poster not found for movieId: 4066.
# Poster not found for movieId: 4067.
# Poster not found for movieId: 4068.
# Poster not found for movieId: 4129.
# Poster not found for movieId: 4130.
# Poster not found for movieId: 4131.
# Poster not found for movieId: 4132.
# Poster not found for movieId: 4133.
# Poster not found for movieId: 4135.
# Poster not found for movieId: 4138.
# Poster not found for movieId: 4139.
# Poster not found for movieId: 4141.
# Poster not found for movieId: 4142.
# Poster not found for movieId: 4143.
# Poster not found for movieId: 4144.
# Poster not found for movieId: 4146.
# Poster not found for movieId: 4147.
# Poster not found for movieId: 4148.
# Poster not found for movieId: 4149.
# Poster not found for movieId: 4152.
# Poster not found for movieId: 4153.
# Poster not found for movieId: 4154.
# Poster not found for movieId: 4155.
# Poster not found for movieId: 4156.
# Poster not found for movieId: 4157.
# Poster not found for movieId: 4158.
# Poster not found for movieId: 4159.
# Poster not found for movieId: 4160.
# Poster not found for movieId: 4161.
# Poster not found for movieId: 4164.
# Poster not found for movieId: 4166.
# Poster not found for movieId: 4167.
# Poster not found for movieId: 4168.
# Poster not found for movieId: 4171.
# Poster not found for movieId: 4174.
# Poster not found for movieId: 4175.
# Poster not found for movieId: 4178.
# Poster not found for movieId: 4180.
# Poster not found for movieId: 4181.
# Poster not found for movieId: 4184.
# Poster not found for movieId: 4187.
# Poster not found for movieId: 4189.
# Poster not found for movieId: 4190.
# Poster not found for movieId: 4191.
# Poster not found for movieId: 4193.
# Poster not found for movieId: 4194.
# Poster not found for movieId: 4195.
# Poster not found for movieId: 4197.
# Poster not found for movieId: 4198.
# Poster not found for movieId: 4200.
# Poster not found for movieId: 4202.
# Poster not found for movieId: 4203.
# Poster not found for movieId: 4204.
# Poster not found for movieId: 4205.
# Poster not found for movieId: 4207.
# Poster not found for movieId: 4210.
# Poster not found for movieId: 4211.
# Poster not found for movieId: 4212.
# Poster not found for movieId: 4214.
# Poster not found for movieId: 4215.
# Poster not found for movieId: 4217.
# Poster not found for movieId: 4218.
# Poster not found for movieId: 4219.
# Poster not found for movieId: 4220.
# Poster not found for movieId: 4221.
# Poster not found for movieId: 4223.
# Poster not found for movieId: 4224.
# Poster not found for movieId: 4225.
# Poster not found for movieId: 4226.
# Poster not found for movieId: 4228.
# Poster not found for movieId: 4229.
# Poster not found for movieId: 4231.
# Poster not found for movieId: 4232.
# Poster not found for movieId: 4233.
# Poster not found for movieId: 4234.
# Poster not found for movieId: 4235.
# Poster not found for movieId: 4236.
# Poster not found for movieId: 4237.
# Poster not found for movieId: 4238.
# Poster not found for movieId: 4239.
# Poster not found for movieId: 4240.
# Poster not found for movieId: 4241.
# Poster not found for movieId: 4242.
# Poster not found for movieId: 4243.
# Poster not found for movieId: 4246.
# Poster not found for movieId: 4247.
# Poster not found for movieId: 4248.
# Poster not found for movieId: 4251.
# Poster not found for movieId: 4252.
# Poster not found for movieId: 4254.
# Poster not found for movieId: 4255.
# Poster not found for movieId: 4256.
# Poster not found for movieId: 4259.
# Poster not found for movieId: 4260.
# Poster not found for movieId: 4262.
# Poster not found for movieId: 4263.
# Poster not found for movieId: 4265.
# Poster not found for movieId: 4267.
# Poster not found for movieId: 4268.
# Poster not found for movieId: 4270.
# Poster not found for movieId: 4273.
# Poster not found for movieId: 4275.
# Poster not found for movieId: 4276.
# Poster not found for movieId: 4278.
# Poster not found for movieId: 4280.
# Poster not found for movieId: 4282.
# Poster not found for movieId: 4284.
# Poster not found for movieId: 4285.
# Poster not found for movieId: 4289.
# Poster not found for movieId: 4290.
# Poster not found for movieId: 4291.
# Poster not found for movieId: 4292.
# Poster not found for movieId: 4293.
# Poster not found for movieId: 4294.
# Poster not found for movieId: 4296.
# Poster not found for movieId: 4297.
# Poster not found for movieId: 4298.
# Poster not found for movieId: 4299.
# Poster not found for movieId: 4300.
# Poster not found for movieId: 4304.
# Poster not found for movieId: 4305.
# Poster not found for movieId: 4306.
# Poster not found for movieId: 4307.
# Poster not found for movieId: 4308.
# Poster not found for movieId: 4310.
# Poster not found for movieId: 4312.
# Poster not found for movieId: 4313.
# Poster not found for movieId: 4316.
# Poster not found for movieId: 4317.
# Poster not found for movieId: 4321.
# Poster not found for movieId: 4322.
# Poster not found for movieId: 4323.
# Poster not found for movieId: 4325.
# Poster not found for movieId: 4326.
# Poster not found for movieId: 4327.
# Poster not found for movieId: 4329.
# Poster not found for movieId: 4333.
# Poster not found for movieId: 4334.
# Poster not found for movieId: 4337.
# Poster not found for movieId: 4338.
# Poster not found for movieId: 4339.
# Poster not found for movieId: 4340.
# Poster not found for movieId: 4342.
# Poster not found for movieId: 4343.
# Poster not found for movieId: 4344.
# Poster not found for movieId: 4345.
# Poster not found for movieId: 4347.
# Poster not found for movieId: 4349.
# Poster not found for movieId: 4350.
# Poster not found for movieId: 4351.
# Poster not found for movieId: 4353.
# Poster not found for movieId: 4354.
# Poster not found for movieId: 4355.
# Poster not found for movieId: 4356.
# Poster not found for movieId: 4357.
# Poster not found for movieId: 4359.
# Poster not found for movieId: 4361.
# Poster not found for movieId: 4366.
# Poster not found for movieId: 4367.
# Poster not found for movieId: 4368.
# Poster not found for movieId: 4369.
# Poster not found for movieId: 4370.
# Poster not found for movieId: 4371.
# Poster not found for movieId: 4372.
# Poster not found for movieId: 4373.
# Poster not found for movieId: 4374.
# Poster not found for movieId: 4378.
# Poster not found for movieId: 4380.
# Poster not found for movieId: 4381.
# Poster not found for movieId: 4383.
# Poster not found for movieId: 4384.
# Poster not found for movieId: 4386.
# Poster not found for movieId: 4387.
# Poster not found for movieId: 4388.
# Poster not found for movieId: 4389.
# Poster not found for movieId: 4390.
# Poster not found for movieId: 4392.
# Poster not found for movieId: 4393.
# Poster not found for movieId: 4394.
# Poster not found for movieId: 4395.
# Poster not found for movieId: 4396.
# Poster not found for movieId: 4397.
# Poster not found for movieId: 4399.
# Poster not found for movieId: 4402.
# Poster not found for movieId: 4403.
# Poster not found for movieId: 4404.
# Poster not found for movieId: 4406.
# Poster not found for movieId: 4407.
# Poster not found for movieId: 4408.
# Poster not found for movieId: 4409.
# Poster not found for movieId: 4410.
# Poster not found for movieId: 4412.
# Poster not found for movieId: 4419.
# Poster not found for movieId: 4420.
# Poster not found for movieId: 4422.
# Poster not found for movieId: 4424.
# Poster not found for movieId: 4426.
# Poster not found for movieId: 4427.
# Poster not found for movieId: 4428.
# Poster not found for movieId: 4429.
# Poster not found for movieId: 4432.
# Poster not found for movieId: 4433.
# Poster not found for movieId: 4434.
# Poster not found for movieId: 4436.
# Poster not found for movieId: 4437.
# Poster not found for movieId: 4438.
# Poster not found for movieId: 4439.
# Poster not found for movieId: 4440.
# Poster not found for movieId: 4441.
# Poster not found for movieId: 4442.
# Poster not found for movieId: 4443.
# Poster not found for movieId: 4444.
# Poster not found for movieId: 4445.
# Poster not found for movieId: 4446.
# Poster not found for movieId: 4447.
# Poster not found for movieId: 4448.
# Poster not found for movieId: 4449.
# Poster not found for movieId: 4450.
# Poster not found for movieId: 4451.
# Poster not found for movieId: 4452.
# Poster not found for movieId: 4453.
# Poster not found for movieId: 4454.
# Poster not found for movieId: 4458.
# Poster not found for movieId: 4459.
# Poster not found for movieId: 4462.
# Poster not found for movieId: 4463.
# Poster not found for movieId: 4464.
# Poster not found for movieId: 4465.
# Poster not found for movieId: 4466.
# Poster not found for movieId: 4467.
# Poster not found for movieId: 4470.
# Poster not found for movieId: 4471.
# Poster not found for movieId: 4473.
# Poster not found for movieId: 4474.
# Poster not found for movieId: 4475.
# Poster not found for movieId: 4476.
# Poster not found for movieId: 4477.
# Poster not found for movieId: 4478.
# Poster not found for movieId: 4480.
# Poster not found for movieId: 4482.
# Poster not found for movieId: 4483.
# Poster not found for movieId: 4484.
# Poster not found for movieId: 4487.
# Poster not found for movieId: 4488.
# Poster not found for movieId: 4489.
# Poster not found for movieId: 4490.
# Poster not found for movieId: 4492.
# Poster not found for movieId: 4495.
# Poster not found for movieId: 4496.
# Poster not found for movieId: 4497.
# Poster not found for movieId: 4498.
# Poster not found for movieId: 4499.
# Poster not found for movieId: 4500.
# Poster not found for movieId: 4502.
# Poster not found for movieId: 4504.
# Poster not found for movieId: 4505.
# Poster not found for movieId: 4506.
# Poster not found for movieId: 4508.
# Poster not found for movieId: 4509.
# Poster not found for movieId: 4511.
# Poster not found for movieId: 4516.
# Poster not found for movieId: 4517.
# Poster not found for movieId: 4518.
# Poster not found for movieId: 4519.
# Poster not found for movieId: 4520.
# Poster not found for movieId: 4521.
# Poster not found for movieId: 4522.
# Poster not found for movieId: 4523.
# Poster not found for movieId: 4524.
# Poster not found for movieId: 4526.
# Poster not found for movieId: 4527.
# Poster not found for movieId: 4529.
# Poster not found for movieId: 4531.
# Poster not found for movieId: 4533.
# Poster not found for movieId: 4534.
# Poster not found for movieId: 4535.
# Poster not found for movieId: 4537.
# Poster not found for movieId: 4541.
# Poster not found for movieId: 4544.
# Poster not found for movieId: 4545.
# Poster not found for movieId: 4546.
# Poster not found for movieId: 4552.
# Poster not found for movieId: 4553.
# Poster not found for movieId: 4557.
# Poster not found for movieId: 4558.
# Poster not found for movieId: 4562.
# Poster not found for movieId: 4563.
# Poster not found for movieId: 4564.
# Poster not found for movieId: 4565.
# Poster not found for movieId: 4568.
# Poster not found for movieId: 4571.
# Poster not found for movieId: 4572.
# Poster not found for movieId: 4573.
# Poster not found for movieId: 4574.
# Poster not found for movieId: 4577.
# Poster not found for movieId: 4578.
# Poster not found for movieId: 4580.
# Poster not found for movieId: 4581.
# Poster not found for movieId: 4583.
# Poster not found for movieId: 4584.
# Poster not found for movieId: 4585.
# Poster not found for movieId: 4587.
# Poster not found for movieId: 4589.
# Poster not found for movieId: 4591.
# Poster not found for movieId: 4593.
# Poster not found for movieId: 4594.
# Poster not found for movieId: 4595.
# Poster not found for movieId: 4597.
# Poster not found for movieId: 4599.
# Poster not found for movieId: 4600.
# Poster not found for movieId: 4602.
# Poster not found for movieId: 4603.
# Poster not found for movieId: 4605.
# Poster not found for movieId: 4608.
# Poster not found for movieId: 4610.
# Poster not found for movieId: 4611.
# Poster not found for movieId: 4612.
# Poster not found for movieId: 4613.
# Poster not found for movieId: 4614.
# Poster not found for movieId: 4615.
# Poster not found for movieId: 4616.
# Poster not found for movieId: 4617.
# Poster not found for movieId: 4619.
# Poster not found for movieId: 4621.
# Poster not found for movieId: 4622.
# Poster not found for movieId: 4623.
# Poster not found for movieId: 4624.
# Poster not found for movieId: 4625.
# Poster not found for movieId: 4626.
# Poster not found for movieId: 4628.
# Poster not found for movieId: 4629.
# Poster not found for movieId: 4630.
# Poster not found for movieId: 4632.
# Poster not found for movieId: 4634.
# Poster not found for movieId: 4635.
# Poster not found for movieId: 4636.
# Poster not found for movieId: 4638.
# Poster not found for movieId: 4639.
# Poster not found for movieId: 4640.
# Poster not found for movieId: 4641.
# Poster not found for movieId: 4642.
# Poster not found for movieId: 4643.
# Poster not found for movieId: 4644.
# Poster not found for movieId: 4645.
# Poster not found for movieId: 4646.
# Poster not found for movieId: 4649.
# Poster not found for movieId: 4653.
# Poster not found for movieId: 4654.
# Poster not found for movieId: 4658.
# Poster not found for movieId: 4660.
# Poster not found for movieId: 4661.
# Poster not found for movieId: 4662.
# Poster not found for movieId: 4663.
# Poster not found for movieId: 4666.
# Poster not found for movieId: 4670.
# Poster not found for movieId: 4671.
# Poster not found for movieId: 4672.
# Poster not found for movieId: 4673.
# Poster not found for movieId: 4675.
# Poster not found for movieId: 4676.
# Poster not found for movieId: 4677.
# Poster not found for movieId: 4678.
# Poster not found for movieId: 4679.
# Poster not found for movieId: 4681.
# Poster not found for movieId: 4683.
# Poster not found for movieId: 4686.
# Poster not found for movieId: 4687.
# Poster not found for movieId: 4688.
# Poster not found for movieId: 4689.
# Poster not found for movieId: 4690.
# Poster not found for movieId: 4695.
# Poster not found for movieId: 4697.
# Poster not found for movieId: 4699.
# Poster not found for movieId: 4700.
# Poster not found for movieId: 4701.
# Poster not found for movieId: 4703.
# Poster not found for movieId: 4704.
# Poster not found for movieId: 4705.
# Poster not found for movieId: 4708.
# Poster not found for movieId: 4709.
# Poster not found for movieId: 4710.
# Poster not found for movieId: 4711.
# Poster not found for movieId: 4713.
# Poster not found for movieId: 4714.
# Poster not found for movieId: 4715.
# Poster not found for movieId: 4717.
# Poster not found for movieId: 4718.
# Poster not found for movieId: 4719.
# Poster not found for movieId: 4720.
# Poster not found for movieId: 4721.
# Poster not found for movieId: 4722.
# Poster not found for movieId: 4723.
# Poster not found for movieId: 4725.
# Poster not found for movieId: 4727.
# Poster not found for movieId: 4728.
# Poster not found for movieId: 4732.
# Poster not found for movieId: 4733.
# Poster not found for movieId: 4734.
# Poster not found for movieId: 4735.
# Poster not found for movieId: 4736.
# Poster not found for movieId: 4738.
# Poster not found for movieId: 4740.
# Poster not found for movieId: 4741.
# Poster not found for movieId: 4743.
# Poster not found for movieId: 4744.
# Poster not found for movieId: 4745.
# Poster not found for movieId: 4748.
# Poster not found for movieId: 4749.
# Poster not found for movieId: 4750.
# Poster not found for movieId: 4754.
# Poster not found for movieId: 4756.
# Poster not found for movieId: 4757.
# Poster not found for movieId: 4759.
# Poster not found for movieId: 4765.
# Poster not found for movieId: 4766.
# Poster not found for movieId: 4769.
# Poster not found for movieId: 4770.
# Poster not found for movieId: 4771.
# Poster not found for movieId: 4772.
# Poster not found for movieId: 4773.
# Poster not found for movieId: 4774.
# Poster not found for movieId: 4775.
# Poster not found for movieId: 4776.
# Poster not found for movieId: 4777.
# Poster not found for movieId: 4780.
# Poster not found for movieId: 4782.
# Poster not found for movieId: 4783.
# Poster not found for movieId: 4784.
# Poster not found for movieId: 4785.
# Poster not found for movieId: 4786.
# Poster not found for movieId: 4787.
# Poster not found for movieId: 4788.
# Poster not found for movieId: 4789.
# Poster not found for movieId: 4792.
# Poster not found for movieId: 4794.
# Poster not found for movieId: 4795.
# Poster not found for movieId: 4796.
# Poster not found for movieId: 4798.
# Poster not found for movieId: 4799.
# Poster not found for movieId: 4800.
# Poster not found for movieId: 4801.
# Poster not found for movieId: 4802.
# Poster not found for movieId: 4803.
# Poster not found for movieId: 4804.
# Poster not found for movieId: 4808.
# Poster not found for movieId: 4809.
# Poster not found for movieId: 4810.
# Poster not found for movieId: 4811.
# Poster not found for movieId: 4812.
# Poster not found for movieId: 4813.
# Poster not found for movieId: 4814.
# Poster not found for movieId: 4815.
# Poster not found for movieId: 4816.
# Poster not found for movieId: 4818.
# Poster not found for movieId: 4821.
# Poster not found for movieId: 4822.
# Poster not found for movieId: 4823.
# Poster not found for movieId: 4825.
# Poster not found for movieId: 4826.
# Poster not found for movieId: 4827.
# Poster not found for movieId: 4828.
# Poster not found for movieId: 4830.
# Poster not found for movieId: 4831.
# Poster not found for movieId: 4833.
# Poster not found for movieId: 4835.
# Poster not found for movieId: 4836.
# Poster not found for movieId: 4840.
# Poster not found for movieId: 4844.
# Poster not found for movieId: 4845.
# Poster not found for movieId: 4846.
# Poster not found for movieId: 4847.
# Poster not found for movieId: 4848.
# Poster not found for movieId: 4849.
# Poster not found for movieId: 4850.
# Poster not found for movieId: 4852.
# Poster not found for movieId: 4855.
# Poster not found for movieId: 4857.
# Poster not found for movieId: 4860.
# Poster not found for movieId: 4862.
# Poster not found for movieId: 4863.
# Poster not found for movieId: 4864.
# Poster not found for movieId: 4865.
# Poster not found for movieId: 4866.
# Poster not found for movieId: 4867.
# Poster not found for movieId: 4871.
# Poster not found for movieId: 4873.
# Poster not found for movieId: 4874.
# Poster not found for movieId: 4876.
# Poster not found for movieId: 4877.
# Poster not found for movieId: 4878.
# Poster not found for movieId: 4879.
# Poster not found for movieId: 4880.
# Poster not found for movieId: 4881.
# Poster not found for movieId: 4883.
# Poster not found for movieId: 4885.
# Poster not found for movieId: 4886.
# Poster not found for movieId: 4887.
# Poster not found for movieId: 4888.
# Poster not found for movieId: 4889.
# Poster not found for movieId: 4890.
# Poster not found for movieId: 4893.
# Poster not found for movieId: 4896.
# Poster not found for movieId: 4898.
# Poster not found for movieId: 4899.
# Poster not found for movieId: 4900.
# Poster not found for movieId: 4901.
# Poster not found for movieId: 4902.
# Poster not found for movieId: 4903.
# Poster not found for movieId: 4909.
# Poster not found for movieId: 4911.
# Poster not found for movieId: 4912.
# Poster not found for movieId: 4914.
# Poster not found for movieId: 4915.
# Poster not found for movieId: 4916.
# Poster not found for movieId: 4917.
# Poster not found for movieId: 4919.
# Poster not found for movieId: 4920.
# Poster not found for movieId: 4921.
# Poster not found for movieId: 4925.
# Poster not found for movieId: 4926.
# Poster not found for movieId: 4927.
# Poster not found for movieId: 4928.
# Poster not found for movieId: 4929.
# Poster not found for movieId: 4932.
# Poster not found for movieId: 4936.
# Poster not found for movieId: 4939.
# Poster not found for movieId: 4941.
# Poster not found for movieId: 4942.
# Poster not found for movieId: 4945.
# Poster not found for movieId: 4946.
# Poster not found for movieId: 4947.
# Poster not found for movieId: 4951.
# Poster not found for movieId: 4952.
# Poster not found for movieId: 4953.
# Poster not found for movieId: 4954.
# Poster not found for movieId: 4956.
# Poster not found for movieId: 4957.
# Poster not found for movieId: 4958.
# Poster not found for movieId: 4959.
# Poster not found for movieId: 4961.
# Poster not found for movieId: 4962.
# Poster not found for movieId: 4963.
# Poster not found for movieId: 4964.
# Poster not found for movieId: 4965.
# Poster not found for movieId: 4966.
# Poster not found for movieId: 4967.
# Poster not found for movieId: 4969.
# Poster not found for movieId: 4970.
# Poster not found for movieId: 4971.
# Poster not found for movieId: 4973.
# Poster not found for movieId: 4974.
# Poster not found for movieId: 4975.
# Poster not found for movieId: 4976.
# Poster not found for movieId: 4977.
# Poster not found for movieId: 4978.
# Poster not found for movieId: 4979.
# Poster not found for movieId: 4980.
# Poster not found for movieId: 4981.
# Poster not found for movieId: 4985.
# Poster not found for movieId: 4987.
# Poster not found for movieId: 4988.
# Poster not found for movieId: 4989.
# Poster not found for movieId: 4990.
# Poster not found for movieId: 4991.
# Poster not found for movieId: 4992.
# Poster not found for movieId: 4993.
# Poster not found for movieId: 4994.
# Poster not found for movieId: 4995.
# Poster not found for movieId: 4998.
# Poster not found for movieId: 5004.
# Poster not found for movieId: 5007.
# Poster not found for movieId: 5008.
# Poster not found for movieId: 5009.
# Poster not found for movieId: 5010.
# Poster not found for movieId: 5011.
# Poster not found for movieId: 5012.
# Poster not found for movieId: 5013.
# Poster not found for movieId: 5014.
# Poster not found for movieId: 5015.
# Poster not found for movieId: 5016.
# Poster not found for movieId: 5021.
# Poster not found for movieId: 5023.
# Poster not found for movieId: 5025.
# Poster not found for movieId: 5026.
# Poster not found for movieId: 5027.
# Poster not found for movieId: 5028.
# Poster not found for movieId: 5033.
# Poster not found for movieId: 5034.
# Poster not found for movieId: 5039.
# Poster not found for movieId: 5040.
# Poster not found for movieId: 5041.
# Poster not found for movieId: 5046.
# Poster not found for movieId: 5047.
# Poster not found for movieId: 5048.
# Poster not found for movieId: 5049.
# Poster not found for movieId: 5051.
# Poster not found for movieId: 5053.
# Poster not found for movieId: 5054.
# Poster not found for movieId: 5055.
# Poster not found for movieId: 5059.
# Poster not found for movieId: 5060.
# Poster not found for movieId: 5062.
# Poster not found for movieId: 5063.
# Poster not found for movieId: 5064.
# Poster not found for movieId: 5065.
# Poster not found for movieId: 5066.
# Poster not found for movieId: 5068.
# Poster not found for movieId: 5069.
# Poster not found for movieId: 5071.
# Poster not found for movieId: 5072.
# Poster not found for movieId: 5073.
# Poster not found for movieId: 5074.
# Poster not found for movieId: 5075.
# Poster not found for movieId: 5076.
# Poster not found for movieId: 5077.
# Poster not found for movieId: 5080.
# Poster not found for movieId: 5081.
# Poster not found for movieId: 5083.
# Poster not found for movieId: 5088.
# Poster not found for movieId: 5092.
# Poster not found for movieId: 5093.
# Poster not found for movieId: 5094.
# Poster not found for movieId: 5095.
# Poster not found for movieId: 5096.
# Poster not found for movieId: 5099.
# Poster not found for movieId: 5102.
# Poster not found for movieId: 5103.
# Poster not found for movieId: 5105.
# Poster not found for movieId: 5106.
# Poster not found for movieId: 5107.
# Poster not found for movieId: 5108.
# Poster not found for movieId: 5109.
# Poster not found for movieId: 5110.
# Poster not found for movieId: 5111.
# Poster not found for movieId: 5112.
# Poster not found for movieId: 5113.
# Poster not found for movieId: 5114.
# Poster not found for movieId: 5116.
# Poster not found for movieId: 5120.
# Poster not found for movieId: 5121.
# Poster not found for movieId: 5127.
# Poster not found for movieId: 5128.
# Poster not found for movieId: 5131.
# Poster not found for movieId: 5134.
# Poster not found for movieId: 5135.
# Poster not found for movieId: 5136.
# Poster not found for movieId: 5137.
# Poster not found for movieId: 5139.
# Poster not found for movieId: 5146.
# Poster not found for movieId: 5147.
# Poster not found for movieId: 5151.
# Poster not found for movieId: 5152.
# Poster not found for movieId: 5155.
# Poster not found for movieId: 5156.
# Poster not found for movieId: 5159.
# Poster not found for movieId: 5165.
# Poster not found for movieId: 5168.
# Poster not found for movieId: 5170.
# Poster not found for movieId: 5171.
# Poster not found for movieId: 5177.
# Poster not found for movieId: 5178.
# Poster not found for movieId: 5181.
# Poster not found for movieId: 5187.
# Poster not found for movieId: 5189.
# Poster not found for movieId: 5197.
# Poster not found for movieId: 5198.
# Poster not found for movieId: 5202.
# Poster not found for movieId: 5205.
# Poster not found for movieId: 5209.
# Poster not found for movieId: 5212.
# Poster not found for movieId: 5213.
# Poster not found for movieId: 5214.
# Poster not found for movieId: 5218.
# Poster not found for movieId: 5219.
# Poster not found for movieId: 5220.
# Poster not found for movieId: 5221.
# Poster not found for movieId: 5222.
# Poster not found for movieId: 5224.
# Poster not found for movieId: 5225.
# Poster not found for movieId: 5226.
# Poster not found for movieId: 5231.
# Poster not found for movieId: 5237.
# Poster not found for movieId: 5238.
# Poster not found for movieId: 5239.
# Poster not found for movieId: 5240.
# Poster not found for movieId: 5241.
# Poster not found for movieId: 5244.
# Poster not found for movieId: 5246.
# Poster not found for movieId: 5247.
# Poster not found for movieId: 5248.
# Poster not found for movieId: 5250.
# Poster not found for movieId: 5254.
# Poster not found for movieId: 5255.
# Poster not found for movieId: 5256.
# Poster not found for movieId: 5258.
# Poster not found for movieId: 5264.
# Poster not found for movieId: 5265.
# Poster not found for movieId: 5266.
# Poster not found for movieId: 5267.
# Poster not found for movieId: 5268.
# Poster not found for movieId: 5269.
# Poster not found for movieId: 5272.
# Poster not found for movieId: 5275.
# Poster not found for movieId: 5278.
# Poster not found for movieId: 5279.
# Poster not found for movieId: 5282.
# Poster not found for movieId: 5283.
# Poster not found for movieId: 5284.
# Poster not found for movieId: 5285.
# Poster not found for movieId: 5288.
# Poster not found for movieId: 5291.
# Poster not found for movieId: 5292.
# Poster not found for movieId: 5293.
# Poster not found for movieId: 5294.
# Poster not found for movieId: 5296.
# Poster not found for movieId: 5297.
# Poster not found for movieId: 5298.
# Poster not found for movieId: 5299.
# Poster not found for movieId: 5300.
# Poster not found for movieId: 5303.
# Poster not found for movieId: 5304.
# Poster not found for movieId: 5307.
# Poster not found for movieId: 5308.
# Poster not found for movieId: 5309.
# Poster not found for movieId: 5311.
# Poster not found for movieId: 5312.
# Poster not found for movieId: 5313.
# Poster not found for movieId: 5316.
# Poster not found for movieId: 5319.
# Poster not found for movieId: 5321.
# Poster not found for movieId: 5322.
# Poster not found for movieId: 5323.
# Poster not found for movieId: 5324.
# Poster not found for movieId: 5325.
# Poster not found for movieId: 5328.
# Poster not found for movieId: 5329.
# Poster not found for movieId: 5333.
# Poster not found for movieId: 5334.
# Poster not found for movieId: 5337.
# Poster not found for movieId: 5338.
# Poster not found for movieId: 5339.
# Poster not found for movieId: 5341.
# Poster not found for movieId: 5345.
# Poster not found for movieId: 5346.
# Poster not found for movieId: 5347.
# Poster not found for movieId: 5348.
# Poster not found for movieId: 5349.
# Poster not found for movieId: 5353.
# Poster not found for movieId: 5356.
# Poster not found for movieId: 5357.
# Poster not found for movieId: 5358.
# Poster not found for movieId: 5361.
# Poster not found for movieId: 5363.
# Poster not found for movieId: 5364.
# Poster not found for movieId: 5365.
# Poster not found for movieId: 5372.
# Poster not found for movieId: 5373.
# Poster not found for movieId: 5375.
# Poster not found for movieId: 5377.
# Poster not found for movieId: 5378.
# Poster not found for movieId: 5379.
# Poster not found for movieId: 5380.
# Poster not found for movieId: 5382.
# Poster not found for movieId: 5384.
# Poster not found for movieId: 5385.
# Poster not found for movieId: 5387.
# Poster not found for movieId: 5388.
# Poster not found for movieId: 5389.
# Poster not found for movieId: 5390.
# Poster not found for movieId: 5391.
# Poster not found for movieId: 5397.
# Poster not found for movieId: 5398.
# Poster not found for movieId: 5400.
# Poster not found for movieId: 5401.
# Poster not found for movieId: 5404.
# Poster not found for movieId: 5409.
# Poster not found for movieId: 5410.
# Poster not found for movieId: 5414.
# Poster not found for movieId: 5415.
# Poster not found for movieId: 5416.
# Poster not found for movieId: 5417.
# Poster not found for movieId: 5418.
# Poster not found for movieId: 5419.
# Poster not found for movieId: 5420.
# Poster not found for movieId: 5421.
# Poster not found for movieId: 5422.
# Poster not found for movieId: 5423.
# Poster not found for movieId: 5424.
# Poster not found for movieId: 5425.
# Poster not found for movieId: 5427.
# Poster not found for movieId: 5428.
# Poster not found for movieId: 5433.
# Poster not found for movieId: 5434.
# Poster not found for movieId: 5435.
# Poster not found for movieId: 5437.
# Poster not found for movieId: 5438.
# Poster not found for movieId: 5440.
# Poster not found for movieId: 5442.
# Poster not found for movieId: 5443.
# Poster not found for movieId: 5444.
# Poster not found for movieId: 5445.
# Poster not found for movieId: 5446.
# Poster not found for movieId: 5447.
# Poster not found for movieId: 5448.
# Poster not found for movieId: 5449.
# Poster not found for movieId: 5450.
# Poster not found for movieId: 5451.
# Poster not found for movieId: 5452.
# Poster not found for movieId: 5454.
# Poster not found for movieId: 5455.
# Poster not found for movieId: 5456.
# Poster not found for movieId: 5458.
# Poster not found for movieId: 5459.
# Poster not found for movieId: 5460.
# Poster not found for movieId: 5461.
# Poster not found for movieId: 5462.
# Poster not found for movieId: 5463.
# Poster not found for movieId: 5464.
# Poster not found for movieId: 5465.
# Poster not found for movieId: 5466.
# Poster not found for movieId: 5468.
# Poster not found for movieId: 5470.
# Poster not found for movieId: 5471.
# Poster not found for movieId: 5472.
# Poster not found for movieId: 5475.
# Poster not found for movieId: 5476.
# Poster not found for movieId: 5477.
# Poster not found for movieId: 5478.
# Poster not found for movieId: 5479.
# Poster not found for movieId: 5480.
# Poster not found for movieId: 5481.
# Poster not found for movieId: 5483.
# Poster not found for movieId: 5485.
# Poster not found for movieId: 5486.
# Poster not found for movieId: 5489.
# Poster not found for movieId: 5490.
# Poster not found for movieId: 5493.
# Poster not found for movieId: 5497.
# Poster not found for movieId: 5498.
# Poster not found for movieId: 5499.
# Poster not found for movieId: 5500.
# Poster not found for movieId: 5501.
# Poster not found for movieId: 5502.
# Poster not found for movieId: 5503.
# Poster not found for movieId: 5504.
# Poster not found for movieId: 5505.
# Poster not found for movieId: 5506.
# Poster not found for movieId: 5507.
# Poster not found for movieId: 5508.
# Poster not found for movieId: 5512.
# Poster not found for movieId: 5513.
# Poster not found for movieId: 5515.
# Poster not found for movieId: 5521.
# Poster not found for movieId: 5522.
# Poster not found for movieId: 5523.
# Poster not found for movieId: 5524.
# Poster not found for movieId: 5525.
# Poster not found for movieId: 5527.
# Poster not found for movieId: 5528.
# Poster not found for movieId: 5529.
# Poster not found for movieId: 5530.
# Poster not found for movieId: 5531.
# Poster not found for movieId: 5532.
# Poster not found for movieId: 5537.
# Poster not found for movieId: 5538.
# Poster not found for movieId: 5539.
# Poster not found for movieId: 5540.
# Poster not found for movieId: 5541.
# Poster not found for movieId: 5543.
# Poster not found for movieId: 5544.
# Poster not found for movieId: 5548.
# Poster not found for movieId: 5550.
# Poster not found for movieId: 5553.
# Poster not found for movieId: 5556.
# Poster not found for movieId: 5560.
# Poster not found for movieId: 5562.
# Poster not found for movieId: 5563.
# Poster not found for movieId: 5564.
# Poster not found for movieId: 5568.
# Poster not found for movieId: 5569.
# Poster not found for movieId: 5570.
# Poster not found for movieId: 5572.
# Poster not found for movieId: 5573.
# Poster not found for movieId: 5574.
# Poster not found for movieId: 5575.
# Poster not found for movieId: 5577.
# Poster not found for movieId: 5580.
# Poster not found for movieId: 5581.
# Poster not found for movieId: 5582.
# Poster not found for movieId: 5584.
# Poster not found for movieId: 5585.
# Poster not found for movieId: 5588.
# Poster not found for movieId: 5589.
# Poster not found for movieId: 5590.
# Poster not found for movieId: 5591.
# Poster not found for movieId: 5596.
# Poster not found for movieId: 5597.
# Poster not found for movieId: 5601.
# Poster not found for movieId: 5602.
# Poster not found for movieId: 5603.
# Poster not found for movieId: 5604.
# Poster not found for movieId: 5607.
# Poster not found for movieId: 5608.
# Poster not found for movieId: 5609.
# Poster not found for movieId: 5610.
# Poster not found for movieId: 5611.
# Poster not found for movieId: 5612.
# Poster not found for movieId: 5613.
# Poster not found for movieId: 5614.
# Poster not found for movieId: 5615.
# Poster not found for movieId: 5617.
# Poster not found for movieId: 5618.
# Poster not found for movieId: 5619.
# Poster not found for movieId: 5620.
# Poster not found for movieId: 5621.
# Poster not found for movieId: 5625.
# Poster not found for movieId: 5628.
# Poster not found for movieId: 5629.
# Poster not found for movieId: 5630.
# Poster not found for movieId: 5632.
# Poster not found for movieId: 5633.
# Poster not found for movieId: 5635.
# Poster not found for movieId: 5636.
# Poster not found for movieId: 5637.
# Poster not found for movieId: 5638.
# Poster not found for movieId: 5640.
# Poster not found for movieId: 5643.
# Poster not found for movieId: 5644.
# Poster not found for movieId: 5646.
# Poster not found for movieId: 5649.
# Poster not found for movieId: 5650.
# Poster not found for movieId: 5651.
# Poster not found for movieId: 5657.
# Poster not found for movieId: 5663.
# Poster not found for movieId: 5664.
# Poster not found for movieId: 5665.
# Poster not found for movieId: 5666.
# Poster not found for movieId: 5667.
# Poster not found for movieId: 5668.
# Poster not found for movieId: 5669.
# Poster not found for movieId: 5670.
# Poster not found for movieId: 5672.
# Poster not found for movieId: 5673.
# Poster not found for movieId: 5675.
# Poster not found for movieId: 5678.
# Poster not found for movieId: 5679.
# Poster not found for movieId: 5680.
# Poster not found for movieId: 5682.
# Poster not found for movieId: 5684.
# Poster not found for movieId: 5685.
# Poster not found for movieId: 5688.
# Poster not found for movieId: 5689.
# Poster not found for movieId: 5690.
# Poster not found for movieId: 5693.
# Poster not found for movieId: 5694.
# Poster not found for movieId: 5696.
# Poster not found for movieId: 5699.
# Poster not found for movieId: 5700.
# Poster not found for movieId: 5704.
# Poster not found for movieId: 5706.
# Poster not found for movieId: 5707.
# Poster not found for movieId: 5710.
# Poster not found for movieId: 5712.
# Poster not found for movieId: 5720.
# Poster not found for movieId: 5721.
# Poster not found for movieId: 5723.
# Poster not found for movieId: 5733.
# Poster not found for movieId: 5735.
# Poster not found for movieId: 5736.
# Poster not found for movieId: 5741.
# Poster not found for movieId: 5742.
# Poster not found for movieId: 5745.
# Poster not found for movieId: 5746.
# Poster not found for movieId: 5747.
# Poster not found for movieId: 5749.
# Poster not found for movieId: 5752.
# Poster not found for movieId: 5755.
# Poster not found for movieId: 5764.
# Poster not found for movieId: 5767.
# Poster not found for movieId: 5768.
# Poster not found for movieId: 5771.
# Poster not found for movieId: 5772.
# Poster not found for movieId: 5773.
# Poster not found for movieId: 5779.
# Poster not found for movieId: 5780.
# Poster not found for movieId: 5782.
# Poster not found for movieId: 5784.
# Poster not found for movieId: 5785.
# Poster not found for movieId: 5786.
# Poster not found for movieId: 5787.
# Poster not found for movieId: 5788.
# Poster not found for movieId: 5791.
# Poster not found for movieId: 5792.
# Poster not found for movieId: 5796.
# Poster not found for movieId: 5797.
# Poster not found for movieId: 5799.
# Poster not found for movieId: 5801.
# Poster not found for movieId: 5802.
# Poster not found for movieId: 5803.
# Poster not found for movieId: 5804.
# Poster not found for movieId: 5809.
# Poster not found for movieId: 5810.
# Poster not found for movieId: 5812.
# Poster not found for movieId: 5816.
# Poster not found for movieId: 5817.
# Poster not found for movieId: 5818.
# Poster not found for movieId: 5820.
# Poster not found for movieId: 5826.
# Poster not found for movieId: 5828.
# Poster not found for movieId: 5829.
# Poster not found for movieId: 5833.
# Poster not found for movieId: 5836.
# Poster not found for movieId: 5838.
# Poster not found for movieId: 5839.
# Poster not found for movieId: 5840.
# Poster not found for movieId: 5841.
# Poster not found for movieId: 5843.
# Poster not found for movieId: 5847.
# Poster not found for movieId: 5849.
# Poster not found for movieId: 5853.
# Poster not found for movieId: 5856.
# Poster not found for movieId: 5863.
# Poster not found for movieId: 5867.
# Poster not found for movieId: 5872.
# Poster not found for movieId: 5873.
# Poster not found for movieId: 5874.
# Poster not found for movieId: 5875.
# Poster not found for movieId: 5876.
# Poster not found for movieId: 5878.
# Poster not found for movieId: 5879.
# Poster not found for movieId: 5880.
# Poster not found for movieId: 5881.
# Poster not found for movieId: 5882.
# Poster not found for movieId: 5883.
# Poster not found for movieId: 5884.
# Poster not found for movieId: 5888.
# Poster not found for movieId: 5889.
# Poster not found for movieId: 5890.
# Poster not found for movieId: 5891.
# Poster not found for movieId: 5893.
# Poster not found for movieId: 5896.
# Poster not found for movieId: 5899.
# Poster not found for movieId: 5900.
# Poster not found for movieId: 5901.
# Poster not found for movieId: 5902.
# Poster not found for movieId: 5903.
# Poster not found for movieId: 5909.
# Poster not found for movieId: 5912.
# Poster not found for movieId: 5915.
# Poster not found for movieId: 5919.
# Poster not found for movieId: 5922.
# Poster not found for movieId: 5925.
# Poster not found for movieId: 5927.
# Poster not found for movieId: 5929.
# Poster not found for movieId: 5932.
# Poster not found for movieId: 5938.
# Poster not found for movieId: 5941.
# Poster not found for movieId: 5942.
# Poster not found for movieId: 5943.
# Poster not found for movieId: 5944.
# Poster not found for movieId: 5945.
# Poster not found for movieId: 5947.
# Poster not found for movieId: 5949.
# Poster not found for movieId: 5951.
# Poster not found for movieId: 5952.
# Poster not found for movieId: 5953.
# Poster not found for movieId: 5954.
# Poster not found for movieId: 5955.
# Poster not found for movieId: 5956.
# Poster not found for movieId: 5957.
# Poster not found for movieId: 5959.
# Poster not found for movieId: 5961.
# Poster not found for movieId: 5962.
# Poster not found for movieId: 5963.
# Poster not found for movieId: 5965.
# Poster not found for movieId: 5968.
# Poster not found for movieId: 5969.
# Poster not found for movieId: 5970.
# Poster not found for movieId: 5971.
# Poster not found for movieId: 5974.
# Poster not found for movieId: 5975.
# Poster not found for movieId: 5979.
# Poster not found for movieId: 5980.
# Poster not found for movieId: 5984.
# Poster not found for movieId: 5986.
# Poster not found for movieId: 5988.
# Poster not found for movieId: 5989.
# Poster not found for movieId: 5990.
# Poster not found for movieId: 5991.
# Poster not found for movieId: 5992.
# Poster not found for movieId: 5993.
# Poster not found for movieId: 5994.
# Poster not found for movieId: 5995.
# Poster not found for movieId: 5999.
# Poster not found for movieId: 6001.
# Poster not found for movieId: 6002.
# Poster not found for movieId: 6003.
# Poster not found for movieId: 6005.
# Poster not found for movieId: 6006.
# Poster not found for movieId: 6009.
# Poster not found for movieId: 6012.
# Poster not found for movieId: 6013.
# Poster not found for movieId: 6014.
# Poster not found for movieId: 6016.
# Poster not found for movieId: 6020.
# Poster not found for movieId: 6021.
# Poster not found for movieId: 6022.
# Poster not found for movieId: 6023.
# Poster not found for movieId: 6025.
# Poster not found for movieId: 6027.
# Poster not found for movieId: 6030.
# Poster not found for movieId: 6031.
# Poster not found for movieId: 6033.
# Poster not found for movieId: 6035.
# Poster not found for movieId: 6036.
# Poster not found for movieId: 6039.
# Poster not found for movieId: 6040.
# Poster not found for movieId: 6041.
# Poster not found for movieId: 6042.
# Poster not found for movieId: 6044.
# Poster not found for movieId: 6049.
# Poster not found for movieId: 6051.
# Poster not found for movieId: 6055.
# Poster not found for movieId: 6057.
# Poster not found for movieId: 6058.
# Poster not found for movieId: 6059.
# Poster not found for movieId: 6060.
# Poster not found for movieId: 6062.
# Poster not found for movieId: 6063.
# Poster not found for movieId: 6064.
# Poster not found for movieId: 6067.
# Poster not found for movieId: 6070.
# Poster not found for movieId: 6078.
# Poster not found for movieId: 6086.
# Poster not found for movieId: 6090.
# Poster not found for movieId: 6093.
# Poster not found for movieId: 6095.
# Poster not found for movieId: 6100.
# Poster not found for movieId: 6101.
# Poster not found for movieId: 6104.
# Poster not found for movieId: 6107.
# Poster not found for movieId: 6111.
# Poster not found for movieId: 6116.
# Poster not found for movieId: 6119.
# Poster not found for movieId: 6122.
# Poster not found for movieId: 6123.
# Poster not found for movieId: 6124.
# Poster not found for movieId: 6125.
# Poster not found for movieId: 6140.
# Poster not found for movieId: 6141.
# Poster not found for movieId: 6143.
# Poster not found for movieId: 6145.
# Poster not found for movieId: 6148.
# Poster not found for movieId: 6153.
# Poster not found for movieId: 6155.
# Poster not found for movieId: 6156.
# ...
# Poster not found for movieId: 160271.
# Poster not found for movieId: 160289.
# Poster not found for movieId: 160341.
# Poster not found for movieId: 160400.
# Poster not found for movieId: 160422.
# Poster not found for movieId: 160438.
# Poster not found for movieId: 160440.
# Poster not found for movieId: 160527.
# Poster not found for movieId: 160563.
# Poster not found for movieId: 160565.
# Poster not found for movieId: 160567.
# Poster not found for movieId: 160569.
# Poster not found for movieId: 160571.
# Poster not found for movieId: 160573.
# Poster not found for movieId: 160644.
# Poster not found for movieId: 160646.
# Poster not found for movieId: 160684.
# Poster not found for movieId: 160718.
# Poster not found for movieId: 160730.
# Poster not found for movieId: 160836.
# Poster not found for movieId: 160848.
# Poster not found for movieId: 160872.
# Poster not found for movieId: 160954.
# Poster not found for movieId: 160978.
# Poster not found for movieId: 160980.
# Poster not found for movieId: 161008.
# Poster not found for movieId: 161024.
# Poster not found for movieId: 161032.
# Poster not found for movieId: 161044.
# Poster not found for movieId: 161127.
# Poster not found for movieId: 161131.
# Poster not found for movieId: 161290.
# Poster not found for movieId: 161354.
# Poster not found for movieId: 161580.
# Poster not found for movieId: 161582.
# Poster not found for movieId: 161594.
# Poster not found for movieId: 161634.
# Poster not found for movieId: 161830.
# Poster not found for movieId: 161918.
# Poster not found for movieId: 161922.
# Poster not found for movieId: 161966.
# Poster not found for movieId: 162082.
# Poster not found for movieId: 162344.
# Poster not found for movieId: 162350.
# Poster not found for movieId: 162414.
# Poster not found for movieId: 162478.
# Poster not found for movieId: 162578.
# Poster not found for movieId: 162590.
# Poster not found for movieId: 162598.
# Poster not found for movieId: 162600.
# Poster not found for movieId: 162602.
# Poster not found for movieId: 162606.
# Poster not found for movieId: 162828.
# Poster not found for movieId: 162968.
# Poster not found for movieId: 162982.
# Poster not found for movieId: 163056.
# Poster not found for movieId: 163072.
# Poster not found for movieId: 163112.
# Poster not found for movieId: 163134.
# Poster not found for movieId: 163386.
# Poster not found for movieId: 163527.
# Poster not found for movieId: 163639.
# Poster not found for movieId: 163645.
# Poster not found for movieId: 163653.
# Poster not found for movieId: 163809.
# Poster not found for movieId: 163925.
# Poster not found for movieId: 163937.
# Poster not found for movieId: 163981.
# Poster not found for movieId: 163985.
# Poster not found for movieId: 164179.
# Poster not found for movieId: 164200.
# Poster not found for movieId: 164226.
# Poster not found for movieId: 164280.
# Poster not found for movieId: 164367.
# Poster not found for movieId: 164375.
# Poster not found for movieId: 164540.
# Poster not found for movieId: 164647.
# Poster not found for movieId: 164655.
# Poster not found for movieId: 164707.
# Poster not found for movieId: 164753.
# Poster not found for movieId: 164881.
# Poster not found for movieId: 164909.
# Poster not found for movieId: 164917.
# Poster not found for movieId: 165075.
# Poster not found for movieId: 165101.
# Poster not found for movieId: 165103.
# Poster not found for movieId: 165139.
# Poster not found for movieId: 165343.
# Poster not found for movieId: 165347.
# Poster not found for movieId: 165483.
# Poster not found for movieId: 165489.
# Poster not found for movieId: 165529.
# Poster not found for movieId: 165549.
# Poster not found for movieId: 165551.
# Poster not found for movieId: 165635.
# Poster not found for movieId: 165639.
# Poster not found for movieId: 165645.
# Poster not found for movieId: 165671.
# Poster not found for movieId: 165843.
# Poster not found for movieId: 165947.
# Poster not found for movieId: 165959.
# Poster not found for movieId: 165969.
# Poster not found for movieId: 166015.
# Poster not found for movieId: 166024.
# Poster not found for movieId: 166183.
# Poster not found for movieId: 166203.
# Poster not found for movieId: 166291.
# Poster not found for movieId: 166461.
# Poster not found for movieId: 166492.
# Poster not found for movieId: 166526.
# Poster not found for movieId: 166528.
# Poster not found for movieId: 166534.
# Poster not found for movieId: 166558.
# Poster not found for movieId: 166568.
# Poster not found for movieId: 166635.
# Poster not found for movieId: 166643.
# Poster not found for movieId: 166705.
# Poster not found for movieId: 166946.
# Poster not found for movieId: 167018.
# Poster not found for movieId: 167036.
# Poster not found for movieId: 167064.
# Poster not found for movieId: 167296.
# Poster not found for movieId: 167370.
# Poster not found for movieId: 167380.
# Poster not found for movieId: 167538.
# Poster not found for movieId: 167570.
# Poster not found for movieId: 167634.
# Poster not found for movieId: 167706.
# Poster not found for movieId: 167732.
# Poster not found for movieId: 167746.
# Poster not found for movieId: 167772.
# Poster not found for movieId: 167790.
# Poster not found for movieId: 167854.
# Poster not found for movieId: 168026.
# Poster not found for movieId: 168090.
# Poster not found for movieId: 168144.
# Poster not found for movieId: 168174.
# Poster not found for movieId: 168218.
# Poster not found for movieId: 168248.
# Poster not found for movieId: 168250.
# Poster not found for movieId: 168252.
# Poster not found for movieId: 168254.
# Poster not found for movieId: 168266.
# Poster not found for movieId: 168326.
# Poster not found for movieId: 168350.
# Poster not found for movieId: 168358.
# Poster not found for movieId: 168366.
# Poster not found for movieId: 168418.
# Poster not found for movieId: 168456.
# Poster not found for movieId: 168492.
# Poster not found for movieId: 168608.
# Poster not found for movieId: 168612.
# Poster not found for movieId: 168632.
# Poster not found for movieId: 168712.
# Poster not found for movieId: 168846.
# Poster not found for movieId: 169034.
# Poster not found for movieId: 169180.
# Poster not found for movieId: 169670.
# Poster not found for movieId: 169904.
# Poster not found for movieId: 169912.
# Poster not found for movieId: 169958.
# Poster not found for movieId: 169982.
# Poster not found for movieId: 169984.
# Poster not found for movieId: 169992.
# Poster not found for movieId: 170289.
# Poster not found for movieId: 170297.
# Poster not found for movieId: 170355.
# Poster not found for movieId: 170357.
# Poster not found for movieId: 170399.
# Poster not found for movieId: 170401.
# Poster not found for movieId: 170411.
# Poster not found for movieId: 170551.
# Poster not found for movieId: 170597.
# Poster not found for movieId: 170697.
# Poster not found for movieId: 170705.
# Poster not found for movieId: 170777.
# Poster not found for movieId: 170813.
# Poster not found for movieId: 170817.
# Poster not found for movieId: 170827.
# Poster not found for movieId: 170837.
# Poster not found for movieId: 170875.
# Poster not found for movieId: 170897.
# Poster not found for movieId: 170907.
# Poster not found for movieId: 170937.
# Poster not found for movieId: 170939.
# Poster not found for movieId: 170945.
# Poster not found for movieId: 170957.
# Poster not found for movieId: 170993.
# Poster not found for movieId: 171011.
# Poster not found for movieId: 171023.
# Poster not found for movieId: 171251.
# Poster not found for movieId: 171495.
# Poster not found for movieId: 171631.
# Poster not found for movieId: 171695.
# Poster not found for movieId: 171701.
# Poster not found for movieId: 171749.
# Poster not found for movieId: 171751.
# Poster not found for movieId: 171759.
# Poster not found for movieId: 171763.
# Poster not found for movieId: 171765.
# Poster not found for movieId: 171811.
# Poster not found for movieId: 171867.
# Poster not found for movieId: 171891.
# Poster not found for movieId: 171917.
# Poster not found for movieId: 172013.
# Poster not found for movieId: 172215.
# Poster not found for movieId: 172229.
# Poster not found for movieId: 172233.
# Poster not found for movieId: 172253.
# Poster not found for movieId: 172321.
# Poster not found for movieId: 172461.
# Poster not found for movieId: 172497.
# Poster not found for movieId: 172547.
# Poster not found for movieId: 172577.
# Poster not found for movieId: 172583.
# Poster not found for movieId: 172585.
# Poster not found for movieId: 172587.
# Poster not found for movieId: 172589.
# Poster not found for movieId: 172591.
# Poster not found for movieId: 172637.
# Poster not found for movieId: 172705.
# Poster not found for movieId: 172793.
# Poster not found for movieId: 172825.
# Poster not found for movieId: 172875.
# Poster not found for movieId: 172881.
# Poster not found for movieId: 172887.
# Poster not found for movieId: 172909.
# Poster not found for movieId: 173145.
# Poster not found for movieId: 173197.
# Poster not found for movieId: 173205.
# Poster not found for movieId: 173209.
# Poster not found for movieId: 173235.
# Poster not found for movieId: 173253.
# Poster not found for movieId: 173255.
# Poster not found for movieId: 173291.
# Poster not found for movieId: 173307.
# Poster not found for movieId: 173317.
# Poster not found for movieId: 173351.
# Poster not found for movieId: 173355.
# Poster not found for movieId: 173535.
# Poster not found for movieId: 173619.
# Poster not found for movieId: 173751.
# Poster not found for movieId: 173873.
# Poster not found for movieId: 173925.
# Poster not found for movieId: 173941.
# Poster not found for movieId: 173963.
# Poster not found for movieId: 174045.
# Poster not found for movieId: 174053.
# Poster not found for movieId: 174055.
# Poster not found for movieId: 174141.
# Poster not found for movieId: 174403.
# Poster not found for movieId: 174479.
# Poster not found for movieId: 174551.
# Poster not found for movieId: 174681.
# Poster not found for movieId: 174727.
# Poster not found for movieId: 174737.
# Poster not found for movieId: 174815.
# Poster not found for movieId: 174909.
# Poster not found for movieId: 175197.
# Poster not found for movieId: 175199.
# Poster not found for movieId: 175293.
# Poster not found for movieId: 175303.
# Poster not found for movieId: 175387.
# Poster not found for movieId: 175397.
# Poster not found for movieId: 175401.
# Poster not found for movieId: 175431.
# Poster not found for movieId: 175435.
# Poster not found for movieId: 175475.
# Poster not found for movieId: 175485.
# Poster not found for movieId: 175569.
# Poster not found for movieId: 175577.
# Poster not found for movieId: 175585.
# Poster not found for movieId: 175661.
# Poster not found for movieId: 175693.
# Poster not found for movieId: 175705.
# Poster not found for movieId: 175707.
# Poster not found for movieId: 175743.
# Poster not found for movieId: 175781.
# Poster not found for movieId: 176051.
# Poster not found for movieId: 176101.
# Poster not found for movieId: 176329.
# Poster not found for movieId: 176371.
# Poster not found for movieId: 176389.
# Poster not found for movieId: 176413.
# Poster not found for movieId: 176415.
# Poster not found for movieId: 176419.
# Poster not found for movieId: 176423.
# Poster not found for movieId: 176579.
# Poster not found for movieId: 176601.
# Poster not found for movieId: 176621.
# Poster not found for movieId: 176751.
# Poster not found for movieId: 176805.
# Poster not found for movieId: 176935.
# Poster not found for movieId: 177185.
# Poster not found for movieId: 177285.
# Poster not found for movieId: 177593.
# Poster not found for movieId: 177615.
# Poster not found for movieId: 177763.
# Poster not found for movieId: 177765.
# Poster not found for movieId: 177939.
# Poster not found for movieId: 178061.
# Poster not found for movieId: 178111.
# Poster not found for movieId: 178129.
# Poster not found for movieId: 178323.
# Poster not found for movieId: 178613.
# Poster not found for movieId: 178615.
# Poster not found for movieId: 178827.
# Poster not found for movieId: 179053.
# Poster not found for movieId: 179073.
# Poster not found for movieId: 179119.
# Poster not found for movieId: 179133.
# Poster not found for movieId: 179135.
# Poster not found for movieId: 179211.
# Poster not found for movieId: 179401.
# Poster not found for movieId: 179427.
# Poster not found for movieId: 179491.
# Poster not found for movieId: 179511.
# Poster not found for movieId: 179709.
# Poster not found for movieId: 179749.
# Poster not found for movieId: 179813.
# Poster not found for movieId: 179815.
# Poster not found for movieId: 179817.
# Poster not found for movieId: 179819.
# Poster not found for movieId: 179953.
# Poster not found for movieId: 180031.
# Poster not found for movieId: 180045.
# Poster not found for movieId: 180095.
# Poster not found for movieId: 180231.
# Poster not found for movieId: 180263.
# Poster not found for movieId: 180265.
# Poster not found for movieId: 180297.
# Poster not found for movieId: 180497.
# Poster not found for movieId: 180777.
# Poster not found for movieId: 180985.
# Poster not found for movieId: 180987.
# Poster not found for movieId: 181065.
# Poster not found for movieId: 181139.
# Poster not found for movieId: 181315.
# Poster not found for movieId: 181413.
# Poster not found for movieId: 181659.
# Poster not found for movieId: 181719.
# Poster not found for movieId: 182293.
# Poster not found for movieId: 182297.
# Poster not found for movieId: 182299.
# Poster not found for movieId: 182639.
# Poster not found for movieId: 182715.
# Poster not found for movieId: 182727.
# Poster not found for movieId: 182731.
# Poster not found for movieId: 182749.
# Poster not found for movieId: 182793.
# Poster not found for movieId: 182823.
# Poster not found for movieId: 183011.
# Poster not found for movieId: 183197.
# Poster not found for movieId: 183199.
# Poster not found for movieId: 183227.
# Poster not found for movieId: 183295.
# Poster not found for movieId: 183301.
# Poster not found for movieId: 183317.
# Poster not found for movieId: 183611.
# Poster not found for movieId: 183635.
# Poster not found for movieId: 183897.
# Poster not found for movieId: 183911.
# Poster not found for movieId: 183959.
# Poster not found for movieId: 184015.
# Poster not found for movieId: 184053.
# Poster not found for movieId: 184245.
# Poster not found for movieId: 184253.
# Poster not found for movieId: 184257.
# Poster not found for movieId: 184349.
# Poster not found for movieId: 184471.
# Poster not found for movieId: 184641.
# Poster not found for movieId: 184721.
# Poster not found for movieId: 184791.
# Poster not found for movieId: 184931.
# Poster not found for movieId: 184987.
# Poster not found for movieId: 184997.
# Poster not found for movieId: 185029.
# Poster not found for movieId: 185031.
# Poster not found for movieId: 185033.
# Poster not found for movieId: 185135.
# Poster not found for movieId: 185435.
# Poster not found for movieId: 185473.
# Poster not found for movieId: 185585.
# Poster not found for movieId: 186587.
# Poster not found for movieId: 187031.
# Poster not found for movieId: 187541.
# Poster not found for movieId: 187593.
# Poster not found for movieId: 187595.
# Poster not found for movieId: 187717.
# Poster not found for movieId: 188189.
# Poster not found for movieId: 188301.
# Poster not found for movieId: 188675.
# Poster not found for movieId: 188751.
# Poster not found for movieId: 188797.
# Poster not found for movieId: 188833.
# Poster not found for movieId: 189043.
# Poster not found for movieId: 189111.
# Poster not found for movieId: 189333.
# Poster not found for movieId: 189381.
# Poster not found for movieId: 189547.
# Poster not found for movieId: 189713.
# Poster not found for movieId: 190183.
# Poster not found for movieId: 190207.
# Poster not found for movieId: 190209.
# Poster not found for movieId: 190213.
# Poster not found for movieId: 190215.
# Poster not found for movieId: 190219.
# Poster not found for movieId: 190221.
# Poster not found for movieId: 191005.
# Poster not found for movieId: 193565.
# Poster not found for movieId: 193567.
# Poster not found for movieId: 193571.
# Poster not found for movieId: 193573.
# Poster not found for movieId: 193579.
# Poster not found for movieId: 193581.
# Poster not found for movieId: 193583.
# Poster not found for movieId: 193585.
# Poster not found for movieId: 193587.
# Poster not found for movieId: 193609.
# Data aggregation complete.
# Data saved to ../data/ml-latest-small/ dir

# %%
movie_row = links_df[links_df.movieId==310]

# %%
people, poster_link = _scrape_movie_metadata_from_tmdb(movie_row)
people
# Out:
# [(269    310
#   Name: movieId, dtype: int64,
#   'Jean-Luc Godard',
#   'Director'),
#  (269    310
#   Name: movieId, dtype: int64,
#   'Jean-Luc Godard',
#   'Screenplay'),
#  (269    310
#   Name: movieId, dtype: int64,
#   'Claude Chabrol',
#   'Story'),
#  (269    310
#   Name: movieId, dtype: int64,
#   'François Truffaut',
#   'Story'),
#  (269    310
#   Name: movieId, dtype: int64,
#   'Jean-Paul Belmondo',
#   'Actor'),
#  (269    310
#   Name: movieId, dtype: int64,
#   'Jean Seberg',
#   'Actor'),
#  (269    310
#   Name: movieId, dtype: int64,
#   'Daniel Boulanger',
#   'Actor'),
#  (269    310
#   Name: movieId, dtype: int64,
#   'Henri-Jacques Huet',
#   'Actor'),
#  (269    310
#   Name: movieId, dtype: int64,
#   'Roger Hanin',
#   'Actor'),
#  (269    310
#   Name: movieId, dtype: int64,
#   'Van Doude',
#   'Actor'),
#  (269    310
#   Name: movieId, dtype: int64,
#   'Claude Mansard',
#   'Actor'),
#  (269    310
#   Name: movieId, dtype: int64,
#   'Liliane Dreyfus',
#   'Actor'),
#  (269    310
#   Name: movieId, dtype: int64,
#   'Unknown',
#   'Actor')]

# %%
poster_link
# Out:
# (269    310
#  Name: movieId, dtype: int64,
#  'https://media.themoviedb.org/t/p/w300_and_h450_bestv2/D1YIS8ljrSxCZvru88OVTgIjid.jpg')

# %%
poster_links_df.shape
# Out:
# (2893, 2)

# %%
movie_people_df.movieId.nunique()
# Out:
# 2893

# %%
movies_df.movieId.nunique()
# Out:
# 9734

# %%
movie_people_df[movie_people_df.movieId==310]
# Out:
# Empty DataFrame
# Columns: [movieId, name, role]
# Index: []

# %%
# Collect all data
movie_people = []
for index, movie_row in links_df.iterrows():
    movie_people.extend(extract_movie_people(movie_row))

# Convert to a DataFrame
movie_people_df = pd.DataFrame(movie_people, columns=['movieId', 'name', 'role'])
# Save to csv
movie_people_df.to_csv('../data/ml-latest-small/movie_people.csv', index=False)

print(movie_people_df.shape)
